# %% [markdown]
# ## Trabajo práctico final
# Victoria Aguirre, Mauricio Enrich, Milagros Maurer y Felipe Pasquet.

# %% [markdown]
# ### Importación de librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import json
import pandas as pd
import seaborn as sns
import random
from collections import defaultdict, Counter
from datetime import datetime, timedelta
import time
ubicacion_items = defaultdict(list)
totales_racks = Counter()

# %% [markdown]
# ### Carga de datos

# %%
with open('stock.json','r',encoding= 'utf-8') as archivo:
  stock = json.load(archivo)

# %%
with open('backlog.json','r',encoding = 'utf-8') as archivo:
  backlog = json.load(archivo)

# %% [markdown]
# Veamos que estructura tienen los datos.

# %%
stock['Rack_00001']
# Out:
# {'Cara_1': [{'Inventory ID': '1U0KF6M5H964WNX',
#    'Cantidad': 4,
#    'Nivel': 2,
#    'Posicion': 2},
#   {'Inventory ID': '1U0KF6M5H964WNX',
#    'Cantidad': 1,
#    'Nivel': 4,
#    'Posicion': 4},
#   {'Inventory ID': '23K4GP7JVCG918G',
#    'Cantidad': 2,
#    'Nivel': 3,
#    'Posicion': 1},
#   {'Inventory ID': '530INC74HG3R08R',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 3},
#   {'Inventory ID': '6OM5CVCNUT5U3VW',
#    'Cantidad': 2,
#    'Nivel': 2,
#    'Posicion': 3},
#   {'Inventory ID': '7438YZGRK3Y43BH',
#    'Cantidad': 1,
#    'Nivel': 5,
#    'Posicion': 2},
#   {'Inventory ID': '9ER87IHTWAOBWZA',
#    'Cantidad': 2,
#    'Nivel': 2,
#    'Posicion': 1},
#   {'Inventory ID': '9ER87IHTWAOBWZA',
#    'Cantidad': 3,
#    'Nivel': 2,
#    'Posicion': 4},
#   {'Inventory ID': '9ER87IHTWAOBWZA',
#    'Cantidad': 2,
#    'Nivel': 4,
#    'Posicion': 2},
#   {'Inventory ID': '9UM8P51BTAL04EU',
#    'Cantidad': 1,
#    'Nivel': 2,
#    'Posicion': 2},
#   {'Inventory ID': 'BCW1MVAP2EYM650',
#    'Cantidad': 1,
#    'Nivel': 2,
#    'Posicion': 4},
#   {'Inventory ID': 'BCW1MVAP2EYM650',
#    'Cantidad': 1,
#    'Nivel': 4,
#    'Posicion': 2},
#   {'Inventory ID': 'BCW1MVAP2EYM650',
#    'Cantidad': 2,
#    'Nivel': 4,
#    'Posicion': 4},
#   {'Inventory ID': 'CNE7QQW4JF6T49N',
#    'Cantidad': 1,
#    'Nivel': 2,
#    'Posicion': 3},
#   {'Inventory ID': 'CNE7QQW4JF6T49N',
#    'Cantidad': 2,
#    'Nivel': 3,
#    'Posicion': 2},
#   {'Inventory ID': 'FU2SOO2QXYHXH7Z',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 3},
#   {'Inventory ID': 'FU2SOO2QXYHXH7Z',
#    'Cantidad': 5,
#    'Nivel': 5,
#    'Posicion': 1},
#   {'Inventory ID': 'HYNKCQRO9V9WK7C',
#    'Cantidad': 0,
#    'Nivel': 1,
#    'Posicion': 2},
#   {'Inventory ID': 'IPYL5J3CR1HFAJS',
#    'Cantidad': 1,
#    'Nivel': 1,
#    'Posicion': 1},
#   {'Inventory ID': 'IZ7U1XBYXZR8DAR',
#    'Cantidad': 1,
#    'Nivel': 4,
#    'Posicion': 3},
#   {'Inventory ID': 'JFB3NCN75EB7OB1',
#    'Cantidad': 1,
#    'Nivel': 1,
#    'Posicion': 1},
#   {'Inventory ID': 'JFB3NCN75EB7OB1',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 4},
#   {'Inventory ID': 'JL6KLZFHI89SUJX',
#    'Cantidad': 4,
#    'Nivel': 1,
#    'Posicion': 2},
#   {'Inventory ID': 'JL6KLZFHI89SUJX',
#    'Cantidad': 1,
#    'Nivel': 2,
#    'Posicion': 1},
#   {'Inventory ID': 'JL6KLZFHI89SUJX',
#    'Cantidad': 3,
#    'Nivel': 4,
#    'Posicion': 1},
#   {'Inventory ID': 'JVTC77KORFAYKH7',
#    'Cantidad': 3,
#    'Nivel': 4,
#    'Posicion': 3},
#   {'Inventory ID': 'L9A775USWNWZG9B',
#    'Cantidad': 3,
#    'Nivel': 2,
#    'Posicion': 3},
#   {'Inventory ID': 'MOWLMJQ85761LIE',
#    'Cantidad': 1,
#    'Nivel': 1,
#    'Posicion': 2},
#   {'Inventory ID': 'NVX4U8JQQNBUTYQ',
#    'Cantidad': 4,
#    'Nivel': 3,
#    'Posicion': 2},
#   {'Inventory ID': 'Q0QKOAZFI2PNOYG',
#    'Cantidad': 1,
#    'Nivel': 4,
#    'Posicion': 3},
#   {'Inventory ID': 'RZ2YO86Z1NATVCE',
#    'Cantidad': 1,
#    'Nivel': 2,
#    'Posicion': 3},
#   {'Inventory ID': 'VAYLC5I4BAUI1O5',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 1},
#   {'Inventory ID': 'VAYLC5I4BAUI1O5',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 4},
#   {'Inventory ID': 'Z8WNS05ZS9IE1AM',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 2},
#   {'Inventory ID': 'ZATOUXE0M42P0TR',
#    'Cantidad': 2,
#    'Nivel': 5,
#    'Posicion': 3},
#   {'Inventory ID': 'ZLNXSBDOGW81F2X',
#    'Cantidad': 2,
#    'Nivel': 1,
#    'Posicion': 1}],
#  'Cara_2': [{'Inventory ID': '1ZRWHOVMAA0QPB7',
#    'Cantidad': 2,
#    'Nivel': 3,
#    'Posicion': 1},
#   {'Inventory ID': '3LYPB63KOILNDQC',
#    'Cantidad': 3,
#    'Nivel': 4,
#    'Posicion': 1},
#   {'Inventory ID': '5UGVDAABV17X0BZ',
#    'Cantidad': 1,
#    'Nivel': 5,
#    'Posicion': 1},
#   {'Inventory ID': '840D5ZCR359WEA3',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 1},
#   {'Inventory ID': '9ZS6Q0NY4QNI0HY',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 1},
#   {'Inventory ID': 'CNE7QQW4JF6T49N',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 1},
#   {'Inventory ID': 'CNE7QQW4JF6T49N',
#    'Cantidad': 1,
#    'Nivel': 5,
#    'Posicion': 1},
#   {'Inventory ID': 'CTS9QUXR68FUNA6',
#    'Cantidad': 2,
#    'Nivel': 4,
#    'Posicion': 1},
#   {'Inventory ID': 'FXHDAB19H5HVCIX',
#    'Cantidad': 2,
#    'Nivel': 2,
#    'Posicion': 1},
#   {'Inventory ID': 'FXHDAB19H5HVCIX',
#    'Cantidad': 2,
#    'Nivel': 4,
#    'Posicion': 1},
#   {'Inventory ID': 'HAOZGL6TEK0ZYPZ',
#    'Cantidad': 1,
#    'Nivel': 5,
#    'Posicion': 1},
#   {'Inventory ID': 'HBE89ZI9PZ14VHF',
#    'Cantidad': 5,
#    'Nivel': 2,
#    'Posicion': 1},
#   {'Inventory ID': 'NIRSS1PB9DT2RYY',
#    'Cantidad': 3,
#    'Nivel': 2,
#    'Posicion': 1},
#   {'Inventory ID': 'R9SO46ZW6DG2457',
#    'Cantidad': 3,
#    'Nivel': 1,
#    'Posicion': 1},
#   {'Inventory ID': 'V6PEB46SCI68ZNZ',
#    'Cantidad': 1,
#    'Nivel': 1,
#    'Posicion': 1},
#   {'Inventory ID': 'Y5I4N9T93Y4O89B',
#    'Cantidad': 1,
#    'Nivel': 5,
#    'Posicion': 1}],
#  'Cara_3': [{'Inventory ID': '35SUAJQLEU87QJH',
#    'Cantidad': 6,
#    'Nivel': 1,
#    'Posicion': 1},
#   {'Inventory ID': '45Q05CTGOZH9B2P',
#    'Cantidad': 15,
#    'Nivel': 1,
#    'Posicion': 1},
#   {'Inventory ID': '45Q05CTGOZH9B2P',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 2},
#   {'Inventory ID': '4UMXV9JLSKAJHV6',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 1},
#   {'Inventory ID': '4X6Y14047P4I5AT',
#    'Cantidad': 1,
#    'Nivel': 2,
#    'Posicion': 4},
#   {'Inventory ID': '6R0DAM247PQS82M',
#    'Cantidad': 1,
#    'Nivel': 4,
#    'Posicion': 3},
#   {'Inventory ID': '70GHBE7BMO6YT8G',
#    'Cantidad': 2,
#    'Nivel': 4,
#    'Posicion': 2},
#   {'Inventory ID': '7AM5VOY1UHGP5CI',
#    'Cantidad': 1,
#    'Nivel': 2,
#    'Posicion': 1},
#   {'Inventory ID': '9JS44PHAGNFUZUA',
#    'Cantidad': 4,
#    'Nivel': 1,
#    'Posicion': 2},
#   {'Inventory ID': '9JS44PHAGNFUZUA',
#    'Cantidad': 1,
#    'Nivel': 4,
#    'Posicion': 1},
#   {'Inventory ID': 'A833G1MZ8UGRKFO',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 3},
#   {'Inventory ID': 'BU1DYIOHV2TYHHK',
#    'Cantidad': 1,
#    'Nivel': 2,
#    'Posicion': 2},
#   {'Inventory ID': 'ENWZ5LUZ82HEDNL',
#    'Cantidad': 1,
#    'Nivel': 1,
#    'Posicion': 1},
#   {'Inventory ID': 'F3O2ENL2EBBB1IK',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 4},
#   {'Inventory ID': 'FZ7N9F2NF1CI41S',
#    'Cantidad': 1,
#    'Nivel': 1,
#    'Posicion': 2},
#   {'Inventory ID': 'HFY576319OW966K',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 3},
#   {'Inventory ID': 'IBD9G3UABCZH68S',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 4},
#   {'Inventory ID': 'IZ7U1XBYXZR8DAR',
#    'Cantidad': 3,
#    'Nivel': 2,
#    'Posicion': 1},
#   {'Inventory ID': 'JEC570I49SE0HRK',
#    'Cantidad': 22,
#    'Nivel': 3,
#    'Posicion': 1},
#   {'Inventory ID': 'K72Q5VYDUVG6EJE',
#    'Cantidad': 3,
#    'Nivel': 4,
#    'Posicion': 3},
#   {'Inventory ID': 'KOPA2H7CD0QR61S',
#    'Cantidad': 1,
#    'Nivel': 1,
#    'Posicion': 2},
#   {'Inventory ID': 'M3VRGVK8DMNHCUT',
#    'Cantidad': 1,
#    'Nivel': 2,
#    'Posicion': 4},
#   {'Inventory ID': 'MGV4WS39FSXVL4L',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 2},
#   {'Inventory ID': 'MGV4WS39FSXVL4L',
#    'Cantidad': 1,
#    'Nivel': 4,
#    'Posicion': 4},
#   {'Inventory ID': 'MGV4WS39FSXVL4L',
#    'Cantidad': 1,
#    'Nivel': 5,
#    'Posicion': 1},
#   {'Inventory ID': 'MOMO7CW7A1BI38U',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 4},
#   {'Inventory ID': 'NSO0NQ0PPDTN27O',
#    'Cantidad': 2,
#    'Nivel': 2,
#    'Posicion': 2},
#   {'Inventory ID': 'ONG0H1ZGIWFFYBF',
#    'Cantidad': 1,
#    'Nivel': 4,
#    'Posicion': 4},
#   {'Inventory ID': 'ONG0H1ZGIWFFYBF',
#    'Cantidad': 1,
#    'Nivel': 5,
#    'Posicion': 2},
#   {'Inventory ID': 'PM1048ASBGR4JAI',
#    'Cantidad': 4,
#    'Nivel': 2,
#    'Posicion': 3},
#   {'Inventory ID': 'PNIA3D229VW5VOF',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 3},
#   {'Inventory ID': 'QLTCUFIVP6RJ9AY',
#    'Cantidad': 2,
#    'Nivel': 3,
#    'Posicion': 1},
#   {'Inventory ID': 'R2RLZ17ID65POPW',
#    'Cantidad': 1,
#    'Nivel': 2,
#    'Posicion': 1},
#   {'Inventory ID': 'R2RLZ17ID65POPW',
#    'Cantidad': 1,
#    'Nivel': 2,
#    'Posicion': 2},
#   {'Inventory ID': 'R4MAB90MX0OFQ32',
#    'Cantidad': 1,
#    'Nivel': 3,
#    'Posicion': 1},
#   {'Inventory ID': 'RBJGZZ1B4LXC90Q',
#    'Cantidad': 1,
#    'Nivel': 4,
#    'Posicion': 1},
#   {'Inventory ID': 'RBJGZZ1B4LXC90Q',
#    'Cantidad': 2,
#    'Nivel': 5,
#    'Posicion': 3},
#   {'Inventory ID': 'S5I4IOE3JBAUJJY',
#    'Cantidad': 7,
#    'Nivel': 3,
#    'Posicion': 3},
#   {'Inventory ID': 'SWNA9DSMCB84EXR',
#    'Cantidad': 1,
#    'Nivel': 1,
#    'Posicion': 1},
#   {'Inventory ID': 'U3N5LD5Y5M9TEIC',
#    'Cantidad': 1,
#    'Nivel': 1,
#    'Posicion': 2},
#   {'Inventory ID': 'XAWQKC3HQ8FZ8ST',
#    'Cantidad': 1,
#    'Nivel': 2,
#    'Posicion': 2},
#   {'Inventory ID': 'YF3HBWPEUGIPY5H',
#    'Cantidad': 1,
#    'Nivel': 2,
#    'Posicion': 4},
#   {'Inventory ID': 'ZP2LNSTLQFDUWU7',
#    'Cantidad': 1,
#    'Nivel': 4,
#    'Posicion': 2}],
#  'Cara_4': [{'Inventory ID': '5I26WT5USJ3RD60',
#    'Cantidad': 3,
#    'Nivel': 1,
#    'Posicion': 1},
#   {'Inventory ID': 'CA1NB100IR7OGG9',
#    'Cantidad': 8,
#    'Nivel': 5,
#    'Posicion': 1},
#   {'Inventory ID': 'I50604RRJXQLDDT',
#    'Cantidad': 7,
#    'Nivel': 3,
#    'Posicion': 1},
#   {'Inventory ID': 'JEK55SA0SRI59NG',
#    'Cantidad': 1,
#    'Nivel': 4,
#    'Posicion': 1},
#   {'Inventory ID': 'K1XJ4BJELZWS7I7',
#    'Cantidad': 3,
#    'Nivel': 1,
#    'Posicion': 1},
#   {'Inventory ID': 'POKB6L1I1EYX3KK',
#    'Cantidad': 6,
#    'Nivel': 2,
#    'Posicion': 1},
#   {'Inventory ID': 'SF8KNETZA67E2ZY',
#    'Cantidad': 3,
#    'Nivel': 1,
#    'Posicion': 1},
#   {'Inventory ID': 'SFJMNGLTRV0XXB4',
#    'Cantidad': 3,
#    'Nivel': 4,
#    'Posicion': 1},
#   {'Inventory ID': 'U1JR52IZ0K385WA',
#    'Cantidad': 2,
#    'Nivel': 4,
#    'Posicion': 1},
#   {'Inventory ID': 'XCEHHFHXMEPKSE2',
#    'Cantidad': 1,
#    'Nivel': 4,
#    'Posicion': 1},
#   {'Inventory ID': 'YJY3I160VK0M9OA',
#    'Cantidad': 1,
#    'Nivel': 2,
#    'Posicion': 1},
#   {'Inventory ID': 'Z8WNS05ZS9IE1AM',
#    'Cantidad': 2,
#    'Nivel': 1,
#    'Posicion': 1},
#   {'Inventory ID': 'Z8WNS05ZS9IE1AM',
#    'Cantidad': 4,
#    'Nivel': 3,
#    'Posicion': 1},
#   {'Inventory ID': 'Z8WNS05ZS9IE1AM',
#    'Cantidad': 2,
#    'Nivel': 5,
#    'Posicion': 1}]}

# %%
backlog['orders'][0]
# Out:
# {'order_id': 'ORD_013387_LXJY4YBS_000',
#  'item_id': 'LXJY4YBSWCX3KBF',
#  'quantity': 1,
#  'creation_date': '2025-10-09T00:00:04.885077',
#  'due_date': '2025-10-09T21:00:00.885077'}

# %%
# Seteamos semilla
np.random.seed(100)
random.seed(100)

# %% [markdown]
# ## Heurística

# %% [markdown]
# ### Limpieza de backlog
#
# Durante el problema, nos dimos cuenta que muchas de las órdenes no cuentan con el stock suficiente para ser suplidas. Es por eso, que dado el backlog original, decidimos hacer una copia nueva, donde unicamente tenga las órdenes que sí tienen stock.

# %%
# pedidos_items devuleve, por item, cuántos pedidos hay de ese item
# devuelve por item, las ordenes de ese item

pedidos_items = {}
pedidos_por_item = {}


for i in range(len(backlog['orders'])):

  item = backlog['orders'][i]['item_id']

  if(item not in pedidos_items):

    pedidos_items[item] = 1
    pedidos_por_item[item] = [backlog['orders'][i]]

  else:

    pedidos_items[item] += 1
    pedidos_por_item[item].append(backlog['orders'][i])

# %%
# se calcula cuanto stock hay de cada item, recorriendo todos los racks y todas sus caras

stock_items = {}

for rack in stock:

    for cara in stock[rack]:

        for i in range(len(stock[rack][cara])):

            item_id = stock[rack][cara][i]['Inventory ID']
            cantidad = stock[rack][cara][i]['Cantidad']

            if item_id not in stock_items and cantidad > 0:

                stock_items[item_id] = cantidad

            elif cantidad > 0:

                stock_items[item_id] += cantidad

# %%
backlog_preprocesado = []

for item in pedidos_items:
    # si el item no está en el stock, el stock es 0
    stock_item_i = stock_items.get(item, 0)
    pedido_item_i = pedidos_items[item]

    if stock_item_i - pedido_item_i < 0: # no hay suficiente stock del item

        cant = pedido_item_i - stock_item_i # cantidad de pedidos que si se pueden suplir

        # si hay menos stock que pedidos, tomamos los que  se pueden cumplir (elegimos quedarnos con los primeros)
        backlog_preprocesado.extend(pedidos_por_item[item][:stock_item_i])

    else:

      backlog_preprocesado.extend(pedidos_por_item[item][:stock_item_i])

print("La cantidad de órdenes a entregar es de:" ,len(backlog_preprocesado))
# Out:
# La cantidad de órdenes a entregar es de: 171746

# %% [markdown]
# Vamos a trabajar con el backlog ordenado por due_date, ya que queremos darle prioridad a aquellas que están próximas a vencerse.

# %%
backlog_ordenado = sorted(backlog_preprocesado, key=lambda x: datetime.fromisoformat(x["due_date"]))

# %% [markdown]
# ### SS (Shelf Selection)

# %%
def construir_ubicacion(stock):

    global ubicacion_items, totales_racks #variables globales del problema
    ubicacion_items = defaultdict(list) # creamos un diccionario para que, para cada item nos devuelva todas las ubicaciones (rack y cara) en las que se encuentra
    totales_racks = defaultdict(int)

    for rack, caras in stock.items():
        for cara, items in caras.items():
            for entry in items:

                item = entry["Inventory ID"]
                cantidad = int(entry["Cantidad"])

                if cantidad <= 0:
                    continue

                ubicacion_items[item].append({
                    "rack": rack,
                    "cara": cara,
                    "cantidad": cantidad
                })

                totales_racks[rack] += cantidad

# %%
construir_ubicacion(stock)

# %% [markdown]
# Acá se puede ver, como dado un ítem, nos devuelve que se encuentra en el rack 01575 en la cara 1, y en el rack 01972 eb la cara 1. En ambos, en 1 cantidad.

# %%
ubicacion_items['000A2DTFPGC7BYO']
# Out:
# [{'rack': 'Rack_01575', 'cara': 'Cara_1', 'cantidad': 1},
#  {'rack': 'Rack_01972', 'cara': 'Cara_1', 'cantidad': 1}]

# %% [markdown]
# Con la función **`definir_racks(orden, racks_calientes, racks_tibios)`** nuestro objetivo es, dado una orden definir un rack y una cara para pickear esa orden, tratando de dismunir el uso de racks tibios y fríos, priorizando el uso de racks calientes. Racks calientes es una matriz de **cant_racks_totales x 4**, donde la posición i,j es 1 si el rack fue usado sobre la ola, 0 en caso contrario. Y los racks tibios son los racks usados en la ola anterior.

# %%
def definir_rack(orden, racks_calientes, racks_tibios):

    global ubicacion_items, totales_racks

    item = orden["item_id"] #item a pickear
    order_id = orden["order_id"]

    rack = ""

    if ubicacion_items[item] == []: # Me fijo si hay stock del item, esto es por si no hay stock
      return None, 0

    stock_item = 0

    for i in range(len(ubicacion_items[item])):
      stock_item += ubicacion_items[item][i]['cantidad']

    if stock_item == 0: #Cuando te quedaste sin stock porque vas completando las ordenes
      return None, 0

    #Si llegamos aca, es porque hay stock

    #CHEQUEO SI HAY RACKS CALIENTES PARA SATISFACER LA ORDEN

    mejor_clasificacion = 50
    index = -1
    for i in range(len(ubicacion_items[item])):

      r = int(ubicacion_items[item][i]['rack'].split('_')[1]) #rack donde se ecnuentra
      c = int(ubicacion_items[item][i]['cara'].split('_')[1]) #cara donde se encuentra

      if ubicacion_items[item][i]['cantidad'] == 0:
        continue

      if racks_calientes[r-1][c-1] == 1:
        clasificacion_actual = 0 # 0 es el costo de ni siquiera moverme del rack en el que estaba

      elif sum(racks_calientes[r-1]) >= 1:
        clasificacion_actual = 1 # 1 es el costo de quedarme en el mismo rack pero cambiar de cara

      elif racks_tibios[r-1] == 1:
        clasificacion_actual = 3 # 3 es el costo de utilizar un rack tibio
      else:
        clasificacion_actual = 5 # 5 si utilizo un rack frío

      if clasificacion_actual < mejor_clasificacion: #Agarro la que me genere un menor costo
        mejor_clasificacion = clasificacion_actual
        index = i

    if index == -1:
      return None, 0

    rack = ubicacion_items[item][index]['rack']
    cara = ubicacion_items[item][index]['cara']
    r = int(rack.split('_')[1])
    c = int(cara.split('_')[1])

    if mejor_clasificacion == 0:
      ubicacion_items[item][index]['cantidad'] -= 1
      costo = 0
      tipo_rack = "Rack Caliente"
    elif mejor_clasificacion == 1:
      ubicacion_items[item][index]['cantidad'] -= 1
      costo = 1
      tipo_rack = "Rack Caliente"
    elif mejor_clasificacion == 3:
      ubicacion_items[item][index]['cantidad'] -= 1
      costo = 3
      tipo_rack = "Rack Tibio"
    elif mejor_clasificacion == 5:
      ubicacion_items[item][index]['cantidad'] -= 1
      costo = 5
      tipo_rack = "Rack Frio"


    totales_racks[rack] -= 1 #Le resto el ítem que acabamos de agarrar correspondiente a esta orden
    racks_calientes[r - 1][c - 1] = 1 #el rack utilizado se vuelve caliente

    tarea = (orden, item, rack, cara, tipo_rack)

    return tarea, costo

# %%
#Inicializamos variables globales

cant_ordenes_vencidas = 0

# %%
def procesar_backlog(racks_calientes, racks_tibios,faltantes, hora_actual): #este tomaba a backlog
  global cant_ordenes_vencidas

  tareas = []
  costo_total = 0
  penalizacion_total = 0

  if faltantes <= 0:
      return tareas, costo_total

  # Ordenar backlog por fecha de vencimiento (más urgentes primero) (CREO QUE NO HACE FALTA)
  ordenes_ordenadas = sorted(
      backlog_final['orders'],
      key=lambda x: datetime.fromisoformat(x["due_date"])
  )

  # Tomar solo las más próximas a vencer
  ordenes_urgentes = ordenes_ordenadas[:faltantes]
  ordenes_asignadas_ids = set()

  for orden in ordenes_urgentes:

      # Clasificar y asignar igual que las pendientes

      tarea_urgente, costo = definir_rack(orden,racks_calientes, racks_tibios)

      if tarea_urgente:
          tareas.append(tarea_urgente)
          costo_total += costo
          ordenes_asignadas_ids.add(orden['order_id'])

  backlog_final['orders'] = [o for o in backlog_final['orders'] if o['order_id'] not in ordenes_asignadas_ids] #elimino del backlog las ordenes ya asignadas

  while len(tareas) < faltantes and backlog_final["orders"]:
      agregado = False  # marca si se agregó algo en esta pasada
      for orden in list(backlog_final["orders"]):  # iterar sobre copia para poder eliminar
          tarea_nueva, costo = definir_rack(orden, racks_calientes, racks_tibios)
          if tarea_nueva:
              tareas.append(tarea_nueva)
              costo_total += costo
              backlog_final["orders"].remove(orden)
              agregado = True
              ordenes_asignadas_ids.add(orden['order_id'])

              due_date = datetime.fromisoformat(orden["due_date"])
              if hora_actual > due_date: # Si la orden se venció, se penaliza
                  penalizacion_total += 100
                  cant_ordenes_vencidas +=1

              if len(tareas) >= faltantes:
                  break
      if not agregado:
          # si no se pudo agregar ninguna orden más (no hay stock válido)
          break

  costo_total += penalizacion_total
  backlog_final['orders'] = [o for o in backlog_final['orders'] if o['order_id'] not in ordenes_asignadas_ids] #elimino del backlog las ordenes ya asignadas

  return tareas, costo_total

# %%
def procesar_pendientes(pendientes, racks_calientes, racks_tibios):
  tareas = []
  costo = 0

  for orden_pendiente in pendientes:

    tarea, costo_tarea = definir_rack(orden_pendiente, racks_calientes, racks_tibios)

    if tarea:
      tareas.append(tarea)
      costo += costo_tarea

  return tareas, costo

# %%
def actualizar_tibios(tareas, racks_tibios, cant_max_tibios):

  for tarea in tareas:

    nro_rack = int(tarea[2].split('_')[1])
    racks_tibios[nro_rack-1] = 1

  if sum(racks_tibios) > cant_max_tibios:

    cant = sum(racks_tibios) - cant_max_tibios

    for i in range(len(racks_tibios)):

      if racks_tibios[i] == 1:

        racks_tibios[i] = 0
        cant -= 1
        if cant == 0:
          break

# %%
def SS(stock,pendientes, N, racks_tibios,cant_racks, hora_actual): #este tomaba a backlog

  racks_calientes = np.zeros((cant_racks, 4))
  # [[1,0,0,0],[0,0,0,0]], tamaño de la matriz 2087x4
  # N - pendientes + no_cumplidas

  cant_max_tibios = int(0.2 * cant_racks)

  tareas_pend, costo_pend = procesar_pendientes(pendientes, racks_calientes, racks_tibios) # primero asignamos las ordenes pendientes

  faltantes = max(0, N - len(tareas_pend))
  tareas_urgentes, costo_urgente = procesar_backlog(racks_calientes, racks_tibios, faltantes, hora_actual) # asignamos N-len(pendientes)

  tareas = tareas_pend + tareas_urgentes
  costo = costo_pend + costo_urgente

  actualizar_tibios(tareas, racks_tibios, cant_max_tibios) # actualizo racks tibios

  resultado = defaultdict(list)
  for tarea in tareas:
    resultado[(tarea[2], tarea[3])].append(tarea[0]['order_id'])

  return resultado, costo # devolvemos pool de tareas y costo total del ciclo

# %%
backlog_preprocesado
# Out:
# [{'order_id': 'ORD_013387_LXJY4YBS_000',
#   'item_id': 'LXJY4YBSWCX3KBF',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:04.885077',
#   'due_date': '2025-10-09T21:00:00.885077'},
#  {'order_id': 'ORD_013387_LXJY4YBS_001',
#   'item_id': 'LXJY4YBSWCX3KBF',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:04.885077',
#   'due_date': '2025-10-09T06:00:00.885077'},
#  {'order_id': 'ORD_004503_0N9X97RY_000',
#   'item_id': '0N9X97RYEKKHWE1',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.143135',
#   'due_date': '2025-10-09T21:00:00.143135'},
#  {'order_id': 'ORD_004503_1H0SDN0A_000',
#   'item_id': '1H0SDN0ATVN17AR',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.143135',
#   'due_date': '2025-10-09T21:00:00.143135'},
#  {'order_id': 'ORD_004503_T28BROHN_000',
#   'item_id': 'T28BROHNZ5LWGKC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.143135',
#   'due_date': '2025-10-09T16:00:00.143135'},
#  {'order_id': 'ORD_004503_T28BROHN_001',
#   'item_id': 'T28BROHNZ5LWGKC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.143135',
#   'due_date': '2025-10-09T06:00:00.143135'},
#  {'order_id': 'ORD_005571_T28BROHN_000',
#   'item_id': 'T28BROHNZ5LWGKC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T06:17:22.527824',
#   'due_date': '2025-10-09T19:00:00.527824'},
#  {'order_id': 'ORD_005571_T28BROHN_001',
#   'item_id': 'T28BROHNZ5LWGKC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T06:17:22.527824',
#   'due_date': '2025-10-09T23:59:00.527824'},
#  {'order_id': 'ORD_004503_AXLT4W5J_000',
#   'item_id': 'AXLT4W5JSAWZZSH',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.143135',
#   'due_date': '2025-10-09T10:00:00.143135'},
#  {'order_id': 'ORD_004503_AXLT4W5J_001',
#   'item_id': 'AXLT4W5JSAWZZSH',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.143135',
#   'due_date': '2025-10-09T19:00:00.143135'},
#  {'order_id': 'ORD_004503_AXLT4W5J_002',
#   'item_id': 'AXLT4W5JSAWZZSH',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.143135',
#   'due_date': '2025-10-09T06:00:00.143135'},
#  {'order_id': 'ORD_004503_GULI0QO7_000',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.143135',
#   'due_date': '2025-10-09T19:00:00.143135'},
#  {'order_id': 'ORD_004503_GULI0QO7_001',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.143135',
#   'due_date': '2025-10-09T10:00:00.143135'},
#  {'order_id': 'ORD_004503_GULI0QO7_002',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.143135',
#   'due_date': '2025-10-09T19:00:00.143135'},
#  {'order_id': 'ORD_004503_GULI0QO7_003',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.143135',
#   'due_date': '2025-10-09T22:00:00.143135'},
#  {'order_id': 'ORD_004503_GULI0QO7_004',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.143135',
#   'due_date': '2025-10-09T06:00:00.143135'},
#  {'order_id': 'ORD_000205_GULI0QO7_000',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:43:05.500785',
#   'due_date': '2025-10-09T10:00:00.500785'},
#  {'order_id': 'ORD_000205_GULI0QO7_001',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:43:05.500785',
#   'due_date': '2025-10-09T10:00:00.500785'},
#  {'order_id': 'ORD_000205_GULI0QO7_002',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:43:05.500785',
#   'due_date': '2025-10-09T16:00:00.500785'},
#  {'order_id': 'ORD_000205_GULI0QO7_003',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:43:05.500785',
#   'due_date': '2025-10-09T23:59:00.500785'},
#  {'order_id': 'ORD_003151_GULI0QO7_000',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:43:25.177948',
#   'due_date': '2025-10-09T19:00:00.177948'},
#  {'order_id': 'ORD_003151_GULI0QO7_001',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:43:25.177948',
#   'due_date': '2025-10-09T06:00:00.177948'},
#  {'order_id': 'ORD_003151_GULI0QO7_002',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:43:25.177948',
#   'due_date': '2025-10-09T22:00:00.177948'},
#  {'order_id': 'ORD_010383_GULI0QO7_000',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T11:03:37.444102',
#   'due_date': '2025-10-09T16:00:00.444102'},
#  {'order_id': 'ORD_010383_GULI0QO7_001',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T11:03:37.444102',
#   'due_date': '2025-10-09T16:00:00.444102'},
#  {'order_id': 'ORD_010383_GULI0QO7_002',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T11:03:37.444102',
#   'due_date': '2025-10-09T16:00:00.444102'},
#  {'order_id': 'ORD_023247_GULI0QO7_000',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T22:35:03.992954',
#   'due_date': '2025-10-10T19:00:00.992954'},
#  {'order_id': 'ORD_023247_GULI0QO7_001',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T22:35:03.992954',
#   'due_date': '2025-10-10T19:00:00.992954'},
#  {'order_id': 'ORD_023247_GULI0QO7_002',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T22:35:03.992954',
#   'due_date': '2025-10-09T23:59:00.992954'},
#  {'order_id': 'ORD_023247_GULI0QO7_003',
#   'item_id': 'GULI0QO7PCTQPEN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T22:35:03.992954',
#   'due_date': '2025-10-10T16:00:00.992954'},
#  {'order_id': 'ORD_004503_Q0ZA1VRW_000',
#   'item_id': 'Q0ZA1VRWEN4X06J',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.143135',
#   'due_date': '2025-10-09T22:00:00.143135'},
#  {'order_id': 'ORD_001365_QS9HWOC6_000',
#   'item_id': 'QS9HWOC65AS9IKY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.478298',
#   'due_date': '2025-10-09T21:00:00.478298'},
#  {'order_id': 'ORD_001365_QS9HWOC6_001',
#   'item_id': 'QS9HWOC65AS9IKY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.478298',
#   'due_date': '2025-10-09T14:00:00.478298'},
#  {'order_id': 'ORD_001365_6UX62J89_000',
#   'item_id': '6UX62J89XYA1OLJ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.478298',
#   'due_date': '2025-10-09T10:00:00.478298'},
#  {'order_id': 'ORD_001365_JCMMRQSG_000',
#   'item_id': 'JCMMRQSG77OIMG7',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.478298',
#   'due_date': '2025-10-09T22:00:00.478298'},
#  {'order_id': 'ORD_001365_ZDQPS392_000',
#   'item_id': 'ZDQPS392Q787K3A',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.478298',
#   'due_date': '2025-10-09T19:00:00.478298'},
#  {'order_id': 'ORD_001365_04TVGBHZ_000',
#   'item_id': '04TVGBHZY75LK73',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.478298',
#   'due_date': '2025-10-09T23:59:00.478298'},
#  {'order_id': 'ORD_001365_04TVGBHZ_001',
#   'item_id': '04TVGBHZY75LK73',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.478298',
#   'due_date': '2025-10-09T16:00:00.478298'},
#  {'order_id': 'ORD_001365_V5NN07FP_000',
#   'item_id': 'V5NN07FPD5FLIE6',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.478298',
#   'due_date': '2025-10-09T22:00:00.478298'},
#  {'order_id': 'ORD_003367_V5NN07FP_000',
#   'item_id': 'V5NN07FPD5FLIE6',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:28:57.395081',
#   'due_date': '2025-10-09T22:00:00.395081'},
#  {'order_id': 'ORD_003367_V5NN07FP_001',
#   'item_id': 'V5NN07FPD5FLIE6',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:28:57.395081',
#   'due_date': '2025-10-09T06:00:00.395081'},
#  {'order_id': 'ORD_003367_V5NN07FP_002',
#   'item_id': 'V5NN07FPD5FLIE6',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:28:57.395081',
#   'due_date': '2025-10-09T14:00:00.395081'},
#  {'order_id': 'ORD_003367_V5NN07FP_003',
#   'item_id': 'V5NN07FPD5FLIE6',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:28:57.395081',
#   'due_date': '2025-10-09T06:00:00.395081'},
#  {'order_id': 'ORD_003367_V5NN07FP_004',
#   'item_id': 'V5NN07FPD5FLIE6',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:28:57.395081',
#   'due_date': '2025-10-09T23:59:00.395081'},
#  {'order_id': 'ORD_005742_V5NN07FP_000',
#   'item_id': 'V5NN07FPD5FLIE6',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:54:55.537679',
#   'due_date': '2025-10-09T19:00:00.537679'},
#  {'order_id': 'ORD_005742_V5NN07FP_001',
#   'item_id': 'V5NN07FPD5FLIE6',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:54:55.537679',
#   'due_date': '2025-10-09T14:00:00.537679'},
#  {'order_id': 'ORD_005742_V5NN07FP_002',
#   'item_id': 'V5NN07FPD5FLIE6',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:54:55.537679',
#   'due_date': '2025-10-09T19:00:00.537679'},
#  {'order_id': 'ORD_001365_N1L2PNU9_000',
#   'item_id': 'N1L2PNU94COK088',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.478298',
#   'due_date': '2025-10-09T19:00:00.478298'},
#  {'order_id': 'ORD_001365_N1L2PNU9_001',
#   'item_id': 'N1L2PNU94COK088',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.478298',
#   'due_date': '2025-10-09T22:00:00.478298'},
#  {'order_id': 'ORD_007533_LNZ9KYHY_000',
#   'item_id': 'LNZ9KYHYCI6F85T',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.721516',
#   'due_date': '2025-10-09T21:00:00.721516'},
#  {'order_id': 'ORD_007533_ZHXZHNE0_000',
#   'item_id': 'ZHXZHNE046G5DTC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.721516',
#   'due_date': '2025-10-09T06:00:00.721516'},
#  {'order_id': 'ORD_007533_ZHXZHNE0_001',
#   'item_id': 'ZHXZHNE046G5DTC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.721516',
#   'due_date': '2025-10-09T10:00:00.721516'},
#  {'order_id': 'ORD_007533_ZHXZHNE0_002',
#   'item_id': 'ZHXZHNE046G5DTC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.721516',
#   'due_date': '2025-10-09T14:00:00.721516'},
#  {'order_id': 'ORD_007533_SL2Y10M7_000',
#   'item_id': 'SL2Y10M7NDZP06Q',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.721516',
#   'due_date': '2025-10-09T06:00:00.721516'},
#  {'order_id': 'ORD_007533_B9V55YMM_000',
#   'item_id': 'B9V55YMM9BSXWVZ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.721516',
#   'due_date': '2025-10-09T21:00:00.721516'},
#  {'order_id': 'ORD_007533_B9V55YMM_001',
#   'item_id': 'B9V55YMM9BSXWVZ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.721516',
#   'due_date': '2025-10-09T14:00:00.721516'},
#  {'order_id': 'ORD_007533_B9V55YMM_002',
#   'item_id': 'B9V55YMM9BSXWVZ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.721516',
#   'due_date': '2025-10-09T14:00:00.721516'},
#  {'order_id': 'ORD_007533_2TNYWWO6_000',
#   'item_id': '2TNYWWO6B4EW460',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.721516',
#   'due_date': '2025-10-09T23:59:00.721516'},
#  {'order_id': 'ORD_007533_2TNYWWO6_001',
#   'item_id': '2TNYWWO6B4EW460',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.721516',
#   'due_date': '2025-10-09T21:00:00.721516'},
#  {'order_id': 'ORD_007533_Q27Z0HRQ_000',
#   'item_id': 'Q27Z0HRQHB5YFX9',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.721516',
#   'due_date': '2025-10-09T10:00:00.721516'},
#  {'order_id': 'ORD_007533_Q27Z0HRQ_001',
#   'item_id': 'Q27Z0HRQHB5YFX9',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.721516',
#   'due_date': '2025-10-09T16:00:00.721516'},
#  {'order_id': 'ORD_007533_Q27Z0HRQ_002',
#   'item_id': 'Q27Z0HRQHB5YFX9',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:09.721516',
#   'due_date': '2025-10-09T23:59:00.721516'},
#  {'order_id': 'ORD_004607_Q27Z0HRQ_000',
#   'item_id': 'Q27Z0HRQHB5YFX9',
#   'quantity': 1,
#   'creation_date': '2025-10-09T09:00:23.713679',
#   'due_date': '2025-10-09T23:59:00.713679'},
#  {'order_id': 'ORD_005330_VCO1UIMJ_000',
#   'item_id': 'VCO1UIMJ9460DWU',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:10.205074',
#   'due_date': '2025-10-09T21:00:00.205074'},
#  {'order_id': 'ORD_005330_VCO1UIMJ_001',
#   'item_id': 'VCO1UIMJ9460DWU',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:10.205074',
#   'due_date': '2025-10-09T19:00:00.205074'},
#  {'order_id': 'ORD_005330_VCO1UIMJ_002',
#   'item_id': 'VCO1UIMJ9460DWU',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:10.205074',
#   'due_date': '2025-10-09T21:00:00.205074'},
#  {'order_id': 'ORD_005330_VCO1UIMJ_003',
#   'item_id': 'VCO1UIMJ9460DWU',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:10.205074',
#   'due_date': '2025-10-09T22:00:00.205074'},
#  {'order_id': 'ORD_023578_VCO1UIMJ_000',
#   'item_id': 'VCO1UIMJ9460DWU',
#   'quantity': 1,
#   'creation_date': '2025-10-09T21:32:58.168742',
#   'due_date': '2025-10-10T19:00:00.168742'},
#  {'order_id': 'ORD_005330_KUTKTSQL_000',
#   'item_id': 'KUTKTSQLDBRFS01',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:10.205074',
#   'due_date': '2025-10-09T22:00:00.205074'},
#  {'order_id': 'ORD_005330_Y83N9NK0_000',
#   'item_id': 'Y83N9NK0LWXY93S',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:10.205074',
#   'due_date': '2025-10-09T14:00:00.205074'},
#  {'order_id': 'ORD_005330_BS3NPKR6_000',
#   'item_id': 'BS3NPKR69857KSJ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:10.205074',
#   'due_date': '2025-10-09T14:00:00.205074'},
#  {'order_id': 'ORD_005330_BS3NPKR6_001',
#   'item_id': 'BS3NPKR69857KSJ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:10.205074',
#   'due_date': '2025-10-09T21:00:00.205074'},
#  {'order_id': 'ORD_014605_BS3NPKR6_000',
#   'item_id': 'BS3NPKR69857KSJ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T12:44:32.680969',
#   'due_date': '2025-10-09T23:59:00.680969'},
#  {'order_id': 'ORD_014605_BS3NPKR6_001',
#   'item_id': 'BS3NPKR69857KSJ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T12:44:32.680969',
#   'due_date': '2025-10-09T16:00:00.680969'},
#  {'order_id': 'ORD_014605_BS3NPKR6_002',
#   'item_id': 'BS3NPKR69857KSJ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T12:44:32.680969',
#   'due_date': '2025-10-09T14:00:00.680969'},
#  {'order_id': 'ORD_015361_BS3NPKR6_000',
#   'item_id': 'BS3NPKR69857KSJ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T13:11:18.756724',
#   'due_date': '2025-10-09T16:00:00.756724'},
#  {'order_id': 'ORD_015361_BS3NPKR6_001',
#   'item_id': 'BS3NPKR69857KSJ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T13:11:18.756724',
#   'due_date': '2025-10-09T19:00:00.756724'},
#  {'order_id': 'ORD_015361_BS3NPKR6_002',
#   'item_id': 'BS3NPKR69857KSJ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T13:11:18.756724',
#   'due_date': '2025-10-09T14:00:00.756724'},
#  {'order_id': 'ORD_001081_9OOPCSH0_000',
#   'item_id': '9OOPCSH0V3E19SS',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:18.643324',
#   'due_date': '2025-10-09T16:00:00.643324'},
#  {'order_id': 'ORD_001081_9OOPCSH0_001',
#   'item_id': '9OOPCSH0V3E19SS',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:18.643324',
#   'due_date': '2025-10-09T23:59:00.643324'},
#  {'order_id': 'ORD_007918_9OOPCSH0_000',
#   'item_id': '9OOPCSH0V3E19SS',
#   'quantity': 1,
#   'creation_date': '2025-10-09T09:51:51.123422',
#   'due_date': '2025-10-09T10:00:00.123422'},
#  {'order_id': 'ORD_007918_9OOPCSH0_001',
#   'item_id': '9OOPCSH0V3E19SS',
#   'quantity': 1,
#   'creation_date': '2025-10-09T09:51:51.123422',
#   'due_date': '2025-10-09T19:00:00.123422'},
#  {'order_id': 'ORD_007918_9OOPCSH0_002',
#   'item_id': '9OOPCSH0V3E19SS',
#   'quantity': 1,
#   'creation_date': '2025-10-09T09:51:51.123422',
#   'due_date': '2025-10-09T14:00:00.123422'},
#  {'order_id': 'ORD_007918_9OOPCSH0_003',
#   'item_id': '9OOPCSH0V3E19SS',
#   'quantity': 1,
#   'creation_date': '2025-10-09T09:51:51.123422',
#   'due_date': '2025-10-09T21:00:00.123422'},
#  {'order_id': 'ORD_007918_9OOPCSH0_004',
#   'item_id': '9OOPCSH0V3E19SS',
#   'quantity': 1,
#   'creation_date': '2025-10-09T09:51:51.123422',
#   'due_date': '2025-10-09T19:00:00.123422'},
#  {'order_id': 'ORD_026990_9OOPCSH0_000',
#   'item_id': '9OOPCSH0V3E19SS',
#   'quantity': 1,
#   'creation_date': '2025-10-09T19:22:51.080513',
#   'due_date': '2025-10-09T22:00:00.080513'},
#  {'order_id': 'ORD_001081_6ZKFN14P_000',
#   'item_id': '6ZKFN14PU50HRUN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:18.643324',
#   'due_date': '2025-10-09T16:00:00.643324'},
#  {'order_id': 'ORD_001081_6ZKFN14P_001',
#   'item_id': '6ZKFN14PU50HRUN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:18.643324',
#   'due_date': '2025-10-09T14:00:00.643324'},
#  {'order_id': 'ORD_008581_6ZKFN14P_000',
#   'item_id': '6ZKFN14PU50HRUN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T08:14:59.909586',
#   'due_date': '2025-10-09T21:00:00.909586'},
#  {'order_id': 'ORD_008581_6ZKFN14P_001',
#   'item_id': '6ZKFN14PU50HRUN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T08:14:59.909586',
#   'due_date': '2025-10-09T21:00:00.909586'},
#  {'order_id': 'ORD_008581_6ZKFN14P_002',
#   'item_id': '6ZKFN14PU50HRUN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T08:14:59.909586',
#   'due_date': '2025-10-09T19:00:00.909586'},
#  {'order_id': 'ORD_000595_FWMV93J0_000',
#   'item_id': 'FWMV93J0DHDKE8V',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:19.374616',
#   'due_date': '2025-10-09T10:00:00.374616'},
#  {'order_id': 'ORD_000595_FWMV93J0_001',
#   'item_id': 'FWMV93J0DHDKE8V',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:19.374616',
#   'due_date': '2025-10-09T19:00:00.374616'},
#  {'order_id': 'ORD_012758_FWMV93J0_000',
#   'item_id': 'FWMV93J0DHDKE8V',
#   'quantity': 1,
#   'creation_date': '2025-10-09T07:28:58.195631',
#   'due_date': '2025-10-09T22:00:00.195631'},
#  {'order_id': 'ORD_012758_FWMV93J0_001',
#   'item_id': 'FWMV93J0DHDKE8V',
#   'quantity': 1,
#   'creation_date': '2025-10-09T07:28:58.195631',
#   'due_date': '2025-10-09T14:00:00.195631'},
#  {'order_id': 'ORD_012758_FWMV93J0_002',
#   'item_id': 'FWMV93J0DHDKE8V',
#   'quantity': 1,
#   'creation_date': '2025-10-09T07:28:58.195631',
#   'due_date': '2025-10-09T22:00:00.195631'},
#  {'order_id': 'ORD_012758_FWMV93J0_003',
#   'item_id': 'FWMV93J0DHDKE8V',
#   'quantity': 1,
#   'creation_date': '2025-10-09T07:28:58.195631',
#   'due_date': '2025-10-09T22:00:00.195631'},
#  {'order_id': 'ORD_000595_JB5HPC5Q_000',
#   'item_id': 'JB5HPC5Q42JJJIK',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:19.374616',
#   'due_date': '2025-10-09T14:00:00.374616'},
#  {'order_id': 'ORD_000595_HDHZO7CM_000',
#   'item_id': 'HDHZO7CMCOV97QR',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:19.374616',
#   'due_date': '2025-10-09T19:00:00.374616'},
#  {'order_id': 'ORD_000595_HDHZO7CM_001',
#   'item_id': 'HDHZO7CMCOV97QR',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:19.374616',
#   'due_date': '2025-10-09T23:59:00.374616'},
#  {'order_id': 'ORD_000595_HDHZO7CM_002',
#   'item_id': 'HDHZO7CMCOV97QR',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:19.374616',
#   'due_date': '2025-10-09T16:00:00.374616'},
#  {'order_id': 'ORD_000595_HDHZO7CM_003',
#   'item_id': 'HDHZO7CMCOV97QR',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:19.374616',
#   'due_date': '2025-10-09T10:00:00.374616'},
#  {'order_id': 'ORD_019608_HDHZO7CM_000',
#   'item_id': 'HDHZO7CMCOV97QR',
#   'quantity': 1,
#   'creation_date': '2025-10-09T12:01:05.429948',
#   'due_date': '2025-10-09T21:00:00.429948'},
#  {'order_id': 'ORD_019608_HDHZO7CM_001',
#   'item_id': 'HDHZO7CMCOV97QR',
#   'quantity': 1,
#   'creation_date': '2025-10-09T12:01:05.429948',
#   'due_date': '2025-10-09T23:59:00.429948'},
#  {'order_id': 'ORD_015990_HDHZO7CM_000',
#   'item_id': 'HDHZO7CMCOV97QR',
#   'quantity': 1,
#   'creation_date': '2025-10-09T16:59:11.087797',
#   'due_date': '2025-10-09T21:00:00.087797'},
#  {'order_id': 'ORD_000595_FD1K0S53_000',
#   'item_id': 'FD1K0S53JWMZJC5',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:19.374616',
#   'due_date': '2025-10-09T23:59:00.374616'},
#  {'order_id': 'ORD_000595_FD1K0S53_001',
#   'item_id': 'FD1K0S53JWMZJC5',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:19.374616',
#   'due_date': '2025-10-09T19:00:00.374616'},
#  {'order_id': 'ORD_007061_FD1K0S53_000',
#   'item_id': 'FD1K0S53JWMZJC5',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:35:32.327705',
#   'due_date': '2025-10-09T10:00:00.327705'},
#  {'order_id': 'ORD_007061_FD1K0S53_001',
#   'item_id': 'FD1K0S53JWMZJC5',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:35:32.327705',
#   'due_date': '2025-10-09T21:00:00.327705'},
#  {'order_id': 'ORD_007061_FD1K0S53_002',
#   'item_id': 'FD1K0S53JWMZJC5',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:35:32.327705',
#   'due_date': '2025-10-09T16:00:00.327705'},
#  {'order_id': 'ORD_007061_FD1K0S53_003',
#   'item_id': 'FD1K0S53JWMZJC5',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:35:32.327705',
#   'due_date': '2025-10-09T22:00:00.327705'},
#  {'order_id': 'ORD_000595_C69EWYXT_000',
#   'item_id': 'C69EWYXT8PRLYDL',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:19.374616',
#   'due_date': '2025-10-09T06:00:00.374616'},
#  {'order_id': 'ORD_000869_SMU51PM0_000',
#   'item_id': 'SMU51PM072HFUOG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:21.287219',
#   'due_date': '2025-10-09T16:00:00.287219'},
#  {'order_id': 'ORD_001371_SMU51PM0_000',
#   'item_id': 'SMU51PM072HFUOG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T07:04:57.707583',
#   'due_date': '2025-10-09T21:00:00.707583'},
#  {'order_id': 'ORD_000869_02J3533F_000',
#   'item_id': '02J3533FI06M5YB',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:21.287219',
#   'due_date': '2025-10-09T06:00:00.287219'},
#  {'order_id': 'ORD_000869_02J3533F_001',
#   'item_id': '02J3533FI06M5YB',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:21.287219',
#   'due_date': '2025-10-09T16:00:00.287219'},
#  {'order_id': 'ORD_000869_02J3533F_002',
#   'item_id': '02J3533FI06M5YB',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:21.287219',
#   'due_date': '2025-10-09T23:59:00.287219'},
#  {'order_id': 'ORD_000869_CVLQA4WC_000',
#   'item_id': 'CVLQA4WCBH4Y5K7',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:21.287219',
#   'due_date': '2025-10-09T23:59:00.287219'},
#  {'order_id': 'ORD_000869_DEM53E3T_000',
#   'item_id': 'DEM53E3T28KULIA',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:21.287219',
#   'due_date': '2025-10-09T21:00:00.287219'},
#  {'order_id': 'ORD_000869_DEM53E3T_001',
#   'item_id': 'DEM53E3T28KULIA',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:21.287219',
#   'due_date': '2025-10-09T21:00:00.287219'},
#  {'order_id': 'ORD_000869_DEM53E3T_002',
#   'item_id': 'DEM53E3T28KULIA',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:21.287219',
#   'due_date': '2025-10-09T19:00:00.287219'},
#  {'order_id': 'ORD_000869_DEM53E3T_003',
#   'item_id': 'DEM53E3T28KULIA',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:21.287219',
#   'due_date': '2025-10-09T14:00:00.287219'},
#  {'order_id': 'ORD_009404_DEM53E3T_000',
#   'item_id': 'DEM53E3T28KULIA',
#   'quantity': 1,
#   'creation_date': '2025-10-09T06:16:42.540697',
#   'due_date': '2025-10-09T14:00:00.540697'},
#  {'order_id': 'ORD_009404_DEM53E3T_001',
#   'item_id': 'DEM53E3T28KULIA',
#   'quantity': 1,
#   'creation_date': '2025-10-09T06:16:42.540697',
#   'due_date': '2025-10-09T21:00:00.540697'},
#  {'order_id': 'ORD_005731_DEM53E3T_000',
#   'item_id': 'DEM53E3T28KULIA',
#   'quantity': 1,
#   'creation_date': '2025-10-09T08:48:48.334315',
#   'due_date': '2025-10-09T21:00:00.334315'},
#  {'order_id': 'ORD_005731_DEM53E3T_001',
#   'item_id': 'DEM53E3T28KULIA',
#   'quantity': 1,
#   'creation_date': '2025-10-09T08:48:48.334315',
#   'due_date': '2025-10-09T10:00:00.334315'},
#  {'order_id': 'ORD_003641_DEM53E3T_000',
#   'item_id': 'DEM53E3T28KULIA',
#   'quantity': 1,
#   'creation_date': '2025-10-09T11:02:15.805320',
#   'due_date': '2025-10-09T22:00:00.805320'},
#  {'order_id': 'ORD_015064_DEM53E3T_000',
#   'item_id': 'DEM53E3T28KULIA',
#   'quantity': 1,
#   'creation_date': '2025-10-09T14:32:38.421031',
#   'due_date': '2025-10-09T23:59:00.421031'},
#  {'order_id': 'ORD_015064_DEM53E3T_001',
#   'item_id': 'DEM53E3T28KULIA',
#   'quantity': 1,
#   'creation_date': '2025-10-09T14:32:38.421031',
#   'due_date': '2025-10-09T16:00:00.421031'},
#  {'order_id': 'ORD_000869_U2JTCVKK_000',
#   'item_id': 'U2JTCVKKN52DWR2',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:21.287219',
#   'due_date': '2025-10-09T21:00:00.287219'},
#  {'order_id': 'ORD_000869_FSGUYVBA_000',
#   'item_id': 'FSGUYVBAQDFAPIP',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:21.287219',
#   'due_date': '2025-10-09T23:59:00.287219'},
#  {'order_id': 'ORD_000869_O72KBV5K_000',
#   'item_id': 'O72KBV5K2207QN9',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:21.287219',
#   'due_date': '2025-10-09T22:00:00.287219'},
#  {'order_id': 'ORD_000869_O72KBV5K_001',
#   'item_id': 'O72KBV5K2207QN9',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:21.287219',
#   'due_date': '2025-10-09T14:00:00.287219'},
#  {'order_id': 'ORD_012227_H7SN3WX3_000',
#   'item_id': 'H7SN3WX3UQ9GS14',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:26.663727',
#   'due_date': '2025-10-09T06:00:00.663727'},
#  {'order_id': 'ORD_012227_H7SN3WX3_001',
#   'item_id': 'H7SN3WX3UQ9GS14',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:26.663727',
#   'due_date': '2025-10-09T14:00:00.663727'},
#  {'order_id': 'ORD_012227_DKNUEFDB_000',
#   'item_id': 'DKNUEFDBLITZ1Y1',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:26.663727',
#   'due_date': '2025-10-09T06:00:00.663727'},
#  {'order_id': 'ORD_012227_WEKJURPE_000',
#   'item_id': 'WEKJURPETTJ4FPW',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:26.663727',
#   'due_date': '2025-10-09T23:59:00.663727'},
#  {'order_id': 'ORD_009899_WEKJURPE_000',
#   'item_id': 'WEKJURPETTJ4FPW',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:56:10.384089',
#   'due_date': '2025-10-09T14:00:00.384089'},
#  {'order_id': 'ORD_004523_76X79HWY_000',
#   'item_id': '76X79HWYN8BDDDH',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:30.853186',
#   'due_date': '2025-10-09T23:59:00.853186'},
#  {'order_id': 'ORD_004523_76X79HWY_001',
#   'item_id': '76X79HWYN8BDDDH',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:30.853186',
#   'due_date': '2025-10-09T22:00:00.853186'},
#  {'order_id': 'ORD_004523_76X79HWY_002',
#   'item_id': '76X79HWYN8BDDDH',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:30.853186',
#   'due_date': '2025-10-09T14:00:00.853186'},
#  {'order_id': 'ORD_004523_ANXEG8DT_000',
#   'item_id': 'ANXEG8DTB82ZG5V',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:30.853186',
#   'due_date': '2025-10-09T23:59:00.853186'},
#  {'order_id': 'ORD_001942_ONECTA7R_000',
#   'item_id': 'ONECTA7RSJZRQ7B',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T22:00:00.130889'},
#  {'order_id': 'ORD_001942_IYTSZXIM_000',
#   'item_id': 'IYTSZXIMN4LYYKG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T19:00:00.130889'},
#  {'order_id': 'ORD_001942_IYTSZXIM_001',
#   'item_id': 'IYTSZXIMN4LYYKG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T14:00:00.130889'},
#  {'order_id': 'ORD_001942_IYTSZXIM_002',
#   'item_id': 'IYTSZXIMN4LYYKG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T22:00:00.130889'},
#  {'order_id': 'ORD_001942_IYTSZXIM_003',
#   'item_id': 'IYTSZXIMN4LYYKG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T16:00:00.130889'},
#  {'order_id': 'ORD_001942_IYTSZXIM_004',
#   'item_id': 'IYTSZXIMN4LYYKG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T10:00:00.130889'},
#  {'order_id': 'ORD_014427_IYTSZXIM_000',
#   'item_id': 'IYTSZXIMN4LYYKG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T13:07:44.750164',
#   'due_date': '2025-10-09T23:59:00.750164'},
#  {'order_id': 'ORD_014427_IYTSZXIM_001',
#   'item_id': 'IYTSZXIMN4LYYKG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T13:07:44.750164',
#   'due_date': '2025-10-09T14:00:00.750164'},
#  {'order_id': 'ORD_014427_IYTSZXIM_002',
#   'item_id': 'IYTSZXIMN4LYYKG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T13:07:44.750164',
#   'due_date': '2025-10-09T21:00:00.750164'},
#  {'order_id': 'ORD_014427_IYTSZXIM_003',
#   'item_id': 'IYTSZXIMN4LYYKG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T13:07:44.750164',
#   'due_date': '2025-10-09T19:00:00.750164'},
#  {'order_id': 'ORD_014427_IYTSZXIM_004',
#   'item_id': 'IYTSZXIMN4LYYKG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T13:07:44.750164',
#   'due_date': '2025-10-09T14:00:00.750164'},
#  {'order_id': 'ORD_001942_DVUO506P_000',
#   'item_id': 'DVUO506PTCKYI5F',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T19:00:00.130889'},
#  {'order_id': 'ORD_001942_DVUO506P_001',
#   'item_id': 'DVUO506PTCKYI5F',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T21:00:00.130889'},
#  {'order_id': 'ORD_002670_DVUO506P_000',
#   'item_id': 'DVUO506PTCKYI5F',
#   'quantity': 1,
#   'creation_date': '2025-10-09T02:27:21.429190',
#   'due_date': '2025-10-09T23:59:00.429190'},
#  {'order_id': 'ORD_002670_DVUO506P_001',
#   'item_id': 'DVUO506PTCKYI5F',
#   'quantity': 1,
#   'creation_date': '2025-10-09T02:27:21.429190',
#   'due_date': '2025-10-09T10:00:00.429190'},
#  {'order_id': 'ORD_002670_DVUO506P_002',
#   'item_id': 'DVUO506PTCKYI5F',
#   'quantity': 1,
#   'creation_date': '2025-10-09T02:27:21.429190',
#   'due_date': '2025-10-09T23:59:00.429190'},
#  {'order_id': 'ORD_001942_3S1P6VYM_000',
#   'item_id': '3S1P6VYMKW9GZXS',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T10:00:00.130889'},
#  {'order_id': 'ORD_001942_0L1ZP2D4_000',
#   'item_id': '0L1ZP2D4KTREJOY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T21:00:00.130889'},
#  {'order_id': 'ORD_001942_7F7NFUD8_000',
#   'item_id': '7F7NFUD83KJVRFQ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T14:00:00.130889'},
#  {'order_id': 'ORD_001942_MT6C2Q22_000',
#   'item_id': 'MT6C2Q22T06SGNC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T19:00:00.130889'},
#  {'order_id': 'ORD_001942_MT6C2Q22_001',
#   'item_id': 'MT6C2Q22T06SGNC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T10:00:00.130889'},
#  {'order_id': 'ORD_001942_MT6C2Q22_002',
#   'item_id': 'MT6C2Q22T06SGNC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T10:00:00.130889'},
#  {'order_id': 'ORD_001942_MT6C2Q22_003',
#   'item_id': 'MT6C2Q22T06SGNC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T06:00:00.130889'},
#  {'order_id': 'ORD_000820_MT6C2Q22_000',
#   'item_id': 'MT6C2Q22T06SGNC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T05:00:09.093761',
#   'due_date': '2025-10-09T21:00:00.093761'},
#  {'order_id': 'ORD_000820_MT6C2Q22_001',
#   'item_id': 'MT6C2Q22T06SGNC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T05:00:09.093761',
#   'due_date': '2025-10-09T21:00:00.093761'},
#  {'order_id': 'ORD_000820_MT6C2Q22_002',
#   'item_id': 'MT6C2Q22T06SGNC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T05:00:09.093761',
#   'due_date': '2025-10-09T10:00:00.093761'},
#  {'order_id': 'ORD_020882_MT6C2Q22_000',
#   'item_id': 'MT6C2Q22T06SGNC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T12:23:55.718146',
#   'due_date': '2025-10-10T10:00:00.718146'},
#  {'order_id': 'ORD_020882_MT6C2Q22_001',
#   'item_id': 'MT6C2Q22T06SGNC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T12:23:55.718146',
#   'due_date': '2025-10-09T14:00:00.718146'},
#  {'order_id': 'ORD_020882_MT6C2Q22_002',
#   'item_id': 'MT6C2Q22T06SGNC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T12:23:55.718146',
#   'due_date': '2025-10-09T23:59:00.718146'},
#  {'order_id': 'ORD_020882_MT6C2Q22_003',
#   'item_id': 'MT6C2Q22T06SGNC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T12:23:55.718146',
#   'due_date': '2025-10-09T21:00:00.718146'},
#  {'order_id': 'ORD_021454_MT6C2Q22_000',
#   'item_id': 'MT6C2Q22T06SGNC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T15:07:06.332547',
#   'due_date': '2025-10-09T16:00:00.332547'},
#  {'order_id': 'ORD_021454_MT6C2Q22_001',
#   'item_id': 'MT6C2Q22T06SGNC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T15:07:06.332547',
#   'due_date': '2025-10-09T16:00:00.332547'},
#  {'order_id': 'ORD_021454_MT6C2Q22_002',
#   'item_id': 'MT6C2Q22T06SGNC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T15:07:06.332547',
#   'due_date': '2025-10-09T19:00:00.332547'},
#  {'order_id': 'ORD_021454_MT6C2Q22_003',
#   'item_id': 'MT6C2Q22T06SGNC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T15:07:06.332547',
#   'due_date': '2025-10-09T19:00:00.332547'},
#  {'order_id': 'ORD_001942_0VRIOP5R_000',
#   'item_id': '0VRIOP5R9OS03B5',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:31.130889',
#   'due_date': '2025-10-09T21:00:00.130889'},
#  {'order_id': 'ORD_006132_4074IUEN_000',
#   'item_id': '4074IUENLJJZT06',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:36.832191',
#   'due_date': '2025-10-09T10:00:00.832191'},
#  {'order_id': 'ORD_012053_4074IUEN_000',
#   'item_id': '4074IUENLJJZT06',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:01:42.648861',
#   'due_date': '2025-10-09T10:00:00.648861'},
#  {'order_id': 'ORD_012053_4074IUEN_001',
#   'item_id': '4074IUENLJJZT06',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:01:42.648861',
#   'due_date': '2025-10-09T14:00:00.648861'},
#  {'order_id': 'ORD_012053_4074IUEN_002',
#   'item_id': '4074IUENLJJZT06',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:01:42.648861',
#   'due_date': '2025-10-09T06:00:00.648861'},
#  {'order_id': 'ORD_004992_7FS3L6KU_000',
#   'item_id': '7FS3L6KUJMUX0QQ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.165444',
#   'due_date': '2025-10-09T23:59:00.165444'},
#  {'order_id': 'ORD_004992_JQF0J8C4_000',
#   'item_id': 'JQF0J8C4T8XSFZ4',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.165444',
#   'due_date': '2025-10-09T10:00:00.165444'},
#  {'order_id': 'ORD_004992_JQF0J8C4_001',
#   'item_id': 'JQF0J8C4T8XSFZ4',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.165444',
#   'due_date': '2025-10-09T10:00:00.165444'},
#  {'order_id': 'ORD_004992_TOBFX9UX_000',
#   'item_id': 'TOBFX9UXSP22UY5',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.165444',
#   'due_date': '2025-10-09T22:00:00.165444'},
#  {'order_id': 'ORD_004992_TOBFX9UX_001',
#   'item_id': 'TOBFX9UXSP22UY5',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.165444',
#   'due_date': '2025-10-09T22:00:00.165444'},
#  {'order_id': 'ORD_004992_TOBFX9UX_002',
#   'item_id': 'TOBFX9UXSP22UY5',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.165444',
#   'due_date': '2025-10-09T10:00:00.165444'},
#  {'order_id': 'ORD_004992_TOBFX9UX_003',
#   'item_id': 'TOBFX9UXSP22UY5',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.165444',
#   'due_date': '2025-10-09T06:00:00.165444'},
#  {'order_id': 'ORD_004992_3NMLUKGE_000',
#   'item_id': '3NMLUKGECCQKNZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.165444',
#   'due_date': '2025-10-09T16:00:00.165444'},
#  {'order_id': 'ORD_004992_3NMLUKGE_001',
#   'item_id': '3NMLUKGECCQKNZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.165444',
#   'due_date': '2025-10-09T16:00:00.165444'},
#  {'order_id': 'ORD_004992_3NMLUKGE_002',
#   'item_id': '3NMLUKGECCQKNZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.165444',
#   'due_date': '2025-10-09T16:00:00.165444'},
#  {'order_id': 'ORD_004992_KGF7DA6L_000',
#   'item_id': 'KGF7DA6L6D11V96',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.165444',
#   'due_date': '2025-10-09T21:00:00.165444'},
#  {'order_id': 'ORD_004992_KGF7DA6L_001',
#   'item_id': 'KGF7DA6L6D11V96',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.165444',
#   'due_date': '2025-10-09T21:00:00.165444'},
#  {'order_id': 'ORD_004992_KGF7DA6L_002',
#   'item_id': 'KGF7DA6L6D11V96',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.165444',
#   'due_date': '2025-10-09T23:59:00.165444'},
#  {'order_id': 'ORD_004992_9JEL95QK_000',
#   'item_id': '9JEL95QKIMS8RGP',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.165444',
#   'due_date': '2025-10-09T14:00:00.165444'},
#  {'order_id': 'ORD_004992_9JEL95QK_001',
#   'item_id': '9JEL95QKIMS8RGP',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.165444',
#   'due_date': '2025-10-09T22:00:00.165444'},
#  {'order_id': 'ORD_001689_2M23R8NQ_000',
#   'item_id': '2M23R8NQTXPXLQD',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.179331',
#   'due_date': '2025-10-09T16:00:00.179331'},
#  {'order_id': 'ORD_001689_SSFUNPXI_000',
#   'item_id': 'SSFUNPXI8GIKBCQ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.179331',
#   'due_date': '2025-10-09T16:00:00.179331'},
#  {'order_id': 'ORD_001689_SSFUNPXI_001',
#   'item_id': 'SSFUNPXI8GIKBCQ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.179331',
#   'due_date': '2025-10-09T22:00:00.179331'},
#  {'order_id': 'ORD_001689_SSFUNPXI_002',
#   'item_id': 'SSFUNPXI8GIKBCQ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.179331',
#   'due_date': '2025-10-09T19:00:00.179331'},
#  {'order_id': 'ORD_001689_NT2B20FE_000',
#   'item_id': 'NT2B20FERVRB6V2',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.179331',
#   'due_date': '2025-10-09T06:00:00.179331'},
#  {'order_id': 'ORD_001689_SCEXLXYJ_000',
#   'item_id': 'SCEXLXYJF5NGCOZ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.179331',
#   'due_date': '2025-10-09T22:00:00.179331'},
#  {'order_id': 'ORD_001689_536TIVTH_000',
#   'item_id': '536TIVTH9DKWGBY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.179331',
#   'due_date': '2025-10-09T10:00:00.179331'},
#  {'order_id': 'ORD_001689_5PV2L61G_000',
#   'item_id': '5PV2L61GSYAUY5S',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.179331',
#   'due_date': '2025-10-09T16:00:00.179331'},
#  {'order_id': 'ORD_001689_QFXZ2GF4_000',
#   'item_id': 'QFXZ2GF4J2OELZ9',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.179331',
#   'due_date': '2025-10-09T16:00:00.179331'},
#  {'order_id': 'ORD_001689_QFXZ2GF4_001',
#   'item_id': 'QFXZ2GF4J2OELZ9',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:40.179331',
#   'due_date': '2025-10-09T06:00:00.179331'},
#  {'order_id': 'ORD_012115_178KH2KP_000',
#   'item_id': '178KH2KP0UPXUZH',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:41.531251',
#   'due_date': '2025-10-09T14:00:00.531251'},
#  {'order_id': 'ORD_012115_MP2JBEYT_000',
#   'item_id': 'MP2JBEYT7IULBZG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:41.531251',
#   'due_date': '2025-10-09T16:00:00.531251'},
#  {'order_id': 'ORD_001289_MP2JBEYT_000',
#   'item_id': 'MP2JBEYT7IULBZG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T05:34:20.743244',
#   'due_date': '2025-10-09T10:00:00.743244'},
#  {'order_id': 'ORD_001289_MP2JBEYT_001',
#   'item_id': 'MP2JBEYT7IULBZG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T05:34:20.743244',
#   'due_date': '2025-10-09T10:00:00.743244'},
#  {'order_id': 'ORD_001289_MP2JBEYT_002',
#   'item_id': 'MP2JBEYT7IULBZG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T05:34:20.743244',
#   'due_date': '2025-10-09T19:00:00.743244'},
#  {'order_id': 'ORD_001289_MP2JBEYT_003',
#   'item_id': 'MP2JBEYT7IULBZG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T05:34:20.743244',
#   'due_date': '2025-10-09T21:00:00.743244'},
#  {'order_id': 'ORD_026388_MP2JBEYT_000',
#   'item_id': 'MP2JBEYT7IULBZG',
#   'quantity': 1,
#   'creation_date': '2025-10-09T22:37:33.270517',
#   'due_date': '2025-10-09T23:59:00.270517'},
#  {'order_id': 'ORD_012115_G5P9G2Q6_000',
#   'item_id': 'G5P9G2Q6YU79V4P',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:41.531251',
#   'due_date': '2025-10-09T16:00:00.531251'},
#  {'order_id': 'ORD_012115_G5P9G2Q6_001',
#   'item_id': 'G5P9G2Q6YU79V4P',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:41.531251',
#   'due_date': '2025-10-09T23:59:00.531251'},
#  {'order_id': 'ORD_005337_G5P9G2Q6_000',
#   'item_id': 'G5P9G2Q6YU79V4P',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:09:45.239784',
#   'due_date': '2025-10-09T16:00:00.239784'},
#  {'order_id': 'ORD_005337_G5P9G2Q6_001',
#   'item_id': 'G5P9G2Q6YU79V4P',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:09:45.239784',
#   'due_date': '2025-10-09T23:59:00.239784'},
#  {'order_id': 'ORD_005337_G5P9G2Q6_002',
#   'item_id': 'G5P9G2Q6YU79V4P',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:09:45.239784',
#   'due_date': '2025-10-09T14:00:00.239784'},
#  {'order_id': 'ORD_012115_ACZQJ7AN_000',
#   'item_id': 'ACZQJ7ANO6S333R',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:41.531251',
#   'due_date': '2025-10-09T23:59:00.531251'},
#  {'order_id': 'ORD_012115_ACZQJ7AN_001',
#   'item_id': 'ACZQJ7ANO6S333R',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:41.531251',
#   'due_date': '2025-10-09T19:00:00.531251'},
#  {'order_id': 'ORD_012115_YXGCUVJI_000',
#   'item_id': 'YXGCUVJIGB59K24',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:41.531251',
#   'due_date': '2025-10-09T21:00:00.531251'},
#  {'order_id': 'ORD_012115_XVMS4J93_000',
#   'item_id': 'XVMS4J93HT5YVNL',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:41.531251',
#   'due_date': '2025-10-09T19:00:00.531251'},
#  {'order_id': 'ORD_012115_XVMS4J93_001',
#   'item_id': 'XVMS4J93HT5YVNL',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:41.531251',
#   'due_date': '2025-10-09T19:00:00.531251'},
#  {'order_id': 'ORD_012115_R1P5Q53T_000',
#   'item_id': 'R1P5Q53TKD4K42G',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:41.531251',
#   'due_date': '2025-10-09T19:00:00.531251'},
#  {'order_id': 'ORD_012115_R1P5Q53T_001',
#   'item_id': 'R1P5Q53TKD4K42G',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:41.531251',
#   'due_date': '2025-10-09T19:00:00.531251'},
#  {'order_id': 'ORD_012417_R1P5Q53T_000',
#   'item_id': 'R1P5Q53TKD4K42G',
#   'quantity': 1,
#   'creation_date': '2025-10-09T11:53:27.510612',
#   'due_date': '2025-10-09T14:00:00.510612'},
#  {'order_id': 'ORD_012417_R1P5Q53T_001',
#   'item_id': 'R1P5Q53TKD4K42G',
#   'quantity': 1,
#   'creation_date': '2025-10-09T11:53:27.510612',
#   'due_date': '2025-10-09T21:00:00.510612'},
#  {'order_id': 'ORD_025139_R1P5Q53T_000',
#   'item_id': 'R1P5Q53TKD4K42G',
#   'quantity': 1,
#   'creation_date': '2025-10-09T23:33:37.416064',
#   'due_date': '2025-10-10T14:00:00.416064'},
#  {'order_id': 'ORD_012115_RMB6CG0D_000',
#   'item_id': 'RMB6CG0D1Y79YDN',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:41.531251',
#   'due_date': '2025-10-09T22:00:00.531251'},
#  {'order_id': 'ORD_001802_M3TCD59E_000',
#   'item_id': 'M3TCD59EX391NSU',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:45.552600',
#   'due_date': '2025-10-09T10:00:00.552600'},
#  {'order_id': 'ORD_001802_M3TCD59E_001',
#   'item_id': 'M3TCD59EX391NSU',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:45.552600',
#   'due_date': '2025-10-09T19:00:00.552600'},
#  {'order_id': 'ORD_001802_M3TCD59E_002',
#   'item_id': 'M3TCD59EX391NSU',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:45.552600',
#   'due_date': '2025-10-09T21:00:00.552600'},
#  {'order_id': 'ORD_001802_MIHDL7XI_000',
#   'item_id': 'MIHDL7XITP1VNWY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:45.552600',
#   'due_date': '2025-10-09T23:59:00.552600'},
#  {'order_id': 'ORD_001802_JYN1I934_000',
#   'item_id': 'JYN1I934KRLVRXX',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:45.552600',
#   'due_date': '2025-10-09T19:00:00.552600'},
#  {'order_id': 'ORD_001802_JYN1I934_001',
#   'item_id': 'JYN1I934KRLVRXX',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:45.552600',
#   'due_date': '2025-10-09T16:00:00.552600'},
#  {'order_id': 'ORD_001802_JYN1I934_002',
#   'item_id': 'JYN1I934KRLVRXX',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:45.552600',
#   'due_date': '2025-10-09T19:00:00.552600'},
#  {'order_id': 'ORD_001802_JYN1I934_003',
#   'item_id': 'JYN1I934KRLVRXX',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:45.552600',
#   'due_date': '2025-10-09T19:00:00.552600'},
#  {'order_id': 'ORD_001802_JYN1I934_004',
#   'item_id': 'JYN1I934KRLVRXX',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:45.552600',
#   'due_date': '2025-10-09T23:59:00.552600'},
#  {'order_id': 'ORD_010164_JYN1I934_000',
#   'item_id': 'JYN1I934KRLVRXX',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:59:42.694748',
#   'due_date': '2025-10-09T19:00:00.694748'},
#  {'order_id': 'ORD_010164_JYN1I934_001',
#   'item_id': 'JYN1I934KRLVRXX',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:59:42.694748',
#   'due_date': '2025-10-09T21:00:00.694748'},
#  {'order_id': 'ORD_010164_JYN1I934_002',
#   'item_id': 'JYN1I934KRLVRXX',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:59:42.694748',
#   'due_date': '2025-10-09T14:00:00.694748'},
#  {'order_id': 'ORD_010164_JYN1I934_003',
#   'item_id': 'JYN1I934KRLVRXX',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:59:42.694748',
#   'due_date': '2025-10-09T22:00:00.694748'},
#  {'order_id': 'ORD_010164_JYN1I934_004',
#   'item_id': 'JYN1I934KRLVRXX',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:59:42.694748',
#   'due_date': '2025-10-09T19:00:00.694748'},
#  {'order_id': 'ORD_005099_JYN1I934_000',
#   'item_id': 'JYN1I934KRLVRXX',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:27:52.404565',
#   'due_date': '2025-10-09T06:00:00.404565'},
#  {'order_id': 'ORD_001802_N2DK2NHY_000',
#   'item_id': 'N2DK2NHY06EKBUJ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:45.552600',
#   'due_date': '2025-10-09T10:00:00.552600'},
#  {'order_id': 'ORD_001802_N2DK2NHY_001',
#   'item_id': 'N2DK2NHY06EKBUJ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:45.552600',
#   'due_date': '2025-10-09T21:00:00.552600'},
#  {'order_id': 'ORD_001802_13XZ4V62_000',
#   'item_id': '13XZ4V625HOMPGQ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:45.552600',
#   'due_date': '2025-10-09T16:00:00.552600'},
#  {'order_id': 'ORD_001802_13XZ4V62_001',
#   'item_id': '13XZ4V625HOMPGQ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:45.552600',
#   'due_date': '2025-10-09T21:00:00.552600'},
#  {'order_id': 'ORD_001802_LAEM1LXJ_000',
#   'item_id': 'LAEM1LXJYX82XKC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:45.552600',
#   'due_date': '2025-10-09T22:00:00.552600'},
#  {'order_id': 'ORD_001802_1GQ78C57_000',
#   'item_id': '1GQ78C57450Y8UH',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:45.552600',
#   'due_date': '2025-10-09T16:00:00.552600'},
#  {'order_id': 'ORD_002544_YDXC6CGH_000',
#   'item_id': 'YDXC6CGHK2HF011',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:46.490020',
#   'due_date': '2025-10-09T23:59:00.490020'},
#  {'order_id': 'ORD_006000_YDXC6CGH_000',
#   'item_id': 'YDXC6CGHK2HF011',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:11:14.968156',
#   'due_date': '2025-10-09T06:00:00.968156'},
#  {'order_id': 'ORD_006000_YDXC6CGH_001',
#   'item_id': 'YDXC6CGHK2HF011',
#   'quantity': 1,
#   'creation_date': '2025-10-09T01:11:14.968156',
#   'due_date': '2025-10-09T23:59:00.968156'},
#  {'order_id': 'ORD_002544_NP1F3XU1_000',
#   'item_id': 'NP1F3XU1NT5RKOE',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:46.490020',
#   'due_date': '2025-10-09T23:59:00.490020'},
#  {'order_id': 'ORD_002544_NP1F3XU1_001',
#   'item_id': 'NP1F3XU1NT5RKOE',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:46.490020',
#   'due_date': '2025-10-09T06:00:00.490020'},
#  {'order_id': 'ORD_017922_NP1F3XU1_000',
#   'item_id': 'NP1F3XU1NT5RKOE',
#   'quantity': 1,
#   'creation_date': '2025-10-09T17:55:29.514641',
#   'due_date': '2025-10-10T06:00:00.514641'},
#  {'order_id': 'ORD_017922_NP1F3XU1_001',
#   'item_id': 'NP1F3XU1NT5RKOE',
#   'quantity': 1,
#   'creation_date': '2025-10-09T17:55:29.514641',
#   'due_date': '2025-10-10T14:00:00.514641'},
#  {'order_id': 'ORD_017922_NP1F3XU1_002',
#   'item_id': 'NP1F3XU1NT5RKOE',
#   'quantity': 1,
#   'creation_date': '2025-10-09T17:55:29.514641',
#   'due_date': '2025-10-09T19:00:00.514641'},
#  {'order_id': 'ORD_017922_NP1F3XU1_003',
#   'item_id': 'NP1F3XU1NT5RKOE',
#   'quantity': 1,
#   'creation_date': '2025-10-09T17:55:29.514641',
#   'due_date': '2025-10-09T22:00:00.514641'},
#  {'order_id': 'ORD_002544_I469WHIY_000',
#   'item_id': 'I469WHIYQJ5GVM4',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:46.490020',
#   'due_date': '2025-10-09T10:00:00.490020'},
#  {'order_id': 'ORD_002544_I469WHIY_001',
#   'item_id': 'I469WHIYQJ5GVM4',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:00:46.490020',
# ...
#   'item_id': '0D4VTHB5T9EKE87',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:53.836580',
#   'due_date': '2025-10-09T21:00:00.836580'},
#  {'order_id': 'ORD_011818_0D4VTHB5_000',
#   'item_id': '0D4VTHB5T9EKE87',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:51:02.363988',
#   'due_date': '2025-10-09T22:00:00.363988'},
#  {'order_id': 'ORD_011818_0D4VTHB5_001',
#   'item_id': '0D4VTHB5T9EKE87',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:51:02.363988',
#   'due_date': '2025-10-09T10:00:00.363988'},
#  {'order_id': 'ORD_011818_0D4VTHB5_002',
#   'item_id': '0D4VTHB5T9EKE87',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:51:02.363988',
#   'due_date': '2025-10-09T23:59:00.363988'},
#  {'order_id': 'ORD_011818_0D4VTHB5_003',
#   'item_id': '0D4VTHB5T9EKE87',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:51:02.363988',
#   'due_date': '2025-10-09T22:00:00.363988'},
#  {'order_id': 'ORD_011818_0D4VTHB5_004',
#   'item_id': '0D4VTHB5T9EKE87',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:51:02.363988',
#   'due_date': '2025-10-09T06:00:00.363988'},
#  {'order_id': 'ORD_006459_0E0T5O3S_000',
#   'item_id': '0E0T5O3S5RD38GD',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:54.396356',
#   'due_date': '2025-10-09T21:00:00.396356'},
#  {'order_id': 'ORD_014267_70JM6961_000',
#   'item_id': '70JM6961N497QJW',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:56.686312',
#   'due_date': '2025-10-09T06:00:00.686312'},
#  {'order_id': 'ORD_014267_70JM6961_001',
#   'item_id': '70JM6961N497QJW',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:56.686312',
#   'due_date': '2025-10-09T19:00:00.686312'},
#  {'order_id': 'ORD_014267_70JM6961_002',
#   'item_id': '70JM6961N497QJW',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:56.686312',
#   'due_date': '2025-10-09T16:00:00.686312'},
#  {'order_id': 'ORD_014267_70JM6961_003',
#   'item_id': '70JM6961N497QJW',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:56.686312',
#   'due_date': '2025-10-09T23:59:00.686312'},
#  {'order_id': 'ORD_014267_70JM6961_004',
#   'item_id': '70JM6961N497QJW',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:56.686312',
#   'due_date': '2025-10-09T14:00:00.686312'},
#  {'order_id': 'ORD_009405_70JM6961_000',
#   'item_id': '70JM6961N497QJW',
#   'quantity': 1,
#   'creation_date': '2025-10-09T03:25:27.645990',
#   'due_date': '2025-10-09T21:00:00.645990'},
#  {'order_id': 'ORD_009405_70JM6961_001',
#   'item_id': '70JM6961N497QJW',
#   'quantity': 1,
#   'creation_date': '2025-10-09T03:25:27.645990',
#   'due_date': '2025-10-09T19:00:00.645990'},
#  {'order_id': 'ORD_014267_9RGABOOF_000',
#   'item_id': '9RGABOOF3N7H553',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:56.686312',
#   'due_date': '2025-10-09T22:00:00.686312'},
#  {'order_id': 'ORD_006318_9RGABOOF_000',
#   'item_id': '9RGABOOF3N7H553',
#   'quantity': 1,
#   'creation_date': '2025-10-09T08:36:28.550951',
#   'due_date': '2025-10-09T19:00:00.550951'},
#  {'order_id': 'ORD_006318_9RGABOOF_001',
#   'item_id': '9RGABOOF3N7H553',
#   'quantity': 1,
#   'creation_date': '2025-10-09T08:36:28.550951',
#   'due_date': '2025-10-09T19:00:00.550951'},
#  {'order_id': 'ORD_014267_DGUQIC2B_000',
#   'item_id': 'DGUQIC2BQM0GPYQ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:56.686312',
#   'due_date': '2025-10-09T19:00:00.686312'},
#  {'order_id': 'ORD_014267_F0KK32BJ_000',
#   'item_id': 'F0KK32BJQOG3B6X',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:56.686312',
#   'due_date': '2025-10-09T19:00:00.686312'},
#  {'order_id': 'ORD_014267_F0KK32BJ_001',
#   'item_id': 'F0KK32BJQOG3B6X',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:56.686312',
#   'due_date': '2025-10-09T21:00:00.686312'},
#  {'order_id': 'ORD_001364_F0KK32BJ_000',
#   'item_id': 'F0KK32BJQOG3B6X',
#   'quantity': 1,
#   'creation_date': '2025-10-09T03:24:42.425345',
#   'due_date': '2025-10-09T06:00:00.425345'},
#  {'order_id': 'ORD_001364_F0KK32BJ_001',
#   'item_id': 'F0KK32BJQOG3B6X',
#   'quantity': 1,
#   'creation_date': '2025-10-09T03:24:42.425345',
#   'due_date': '2025-10-09T10:00:00.425345'},
#  {'order_id': 'ORD_001364_F0KK32BJ_002',
#   'item_id': 'F0KK32BJQOG3B6X',
#   'quantity': 1,
#   'creation_date': '2025-10-09T03:24:42.425345',
#   'due_date': '2025-10-09T06:00:00.425345'},
#  {'order_id': 'ORD_014267_PGQVC7PV_000',
#   'item_id': 'PGQVC7PV72O9R55',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:56.686312',
#   'due_date': '2025-10-09T21:00:00.686312'},
#  {'order_id': 'ORD_014267_PGQVC7PV_001',
#   'item_id': 'PGQVC7PV72O9R55',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:56.686312',
#   'due_date': '2025-10-09T21:00:00.686312'},
#  {'order_id': 'ORD_014267_PGQVC7PV_002',
#   'item_id': 'PGQVC7PV72O9R55',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:56.686312',
#   'due_date': '2025-10-09T22:00:00.686312'},
#  {'order_id': 'ORD_014267_PGQVC7PV_003',
#   'item_id': 'PGQVC7PV72O9R55',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:56.686312',
#   'due_date': '2025-10-09T21:00:00.686312'},
#  {'order_id': 'ORD_014267_PGQVC7PV_004',
#   'item_id': 'PGQVC7PV72O9R55',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:56.686312',
#   'due_date': '2025-10-09T23:59:00.686312'},
#  {'order_id': 'ORD_007576_79QFKH7Y_000',
#   'item_id': '79QFKH7Y9VHOBO0',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:57.485972',
#   'due_date': '2025-10-09T21:00:00.485972'},
#  {'order_id': 'ORD_007576_79QFKH7Y_001',
#   'item_id': '79QFKH7Y9VHOBO0',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:02:57.485972',
#   'due_date': '2025-10-09T14:00:00.485972'},
#  {'order_id': 'ORD_001363_2R4AJCO3_000',
#   'item_id': '2R4AJCO347FBJ3M',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:01.404451',
#   'due_date': '2025-10-09T16:00:00.404451'},
#  {'order_id': 'ORD_001363_2R4AJCO3_001',
#   'item_id': '2R4AJCO347FBJ3M',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:01.404451',
#   'due_date': '2025-10-09T19:00:00.404451'},
#  {'order_id': 'ORD_001363_WZMDZYBO_000',
#   'item_id': 'WZMDZYBOLEGV90M',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:01.404451',
#   'due_date': '2025-10-09T21:00:00.404451'},
#  {'order_id': 'ORD_001363_WZMDZYBO_001',
#   'item_id': 'WZMDZYBOLEGV90M',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:01.404451',
#   'due_date': '2025-10-09T06:00:00.404451'},
#  {'order_id': 'ORD_013242_S4ROQ6I6_000',
#   'item_id': 'S4ROQ6I6RFL1RTW',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:09.601196',
#   'due_date': '2025-10-09T10:00:00.601196'},
#  {'order_id': 'ORD_013242_JF93BCQH_000',
#   'item_id': 'JF93BCQHFXA1A3H',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:09.601196',
#   'due_date': '2025-10-09T23:59:00.601196'},
#  {'order_id': 'ORD_002983_U2TFHYDC_000',
#   'item_id': 'U2TFHYDC598P7SI',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:17.890026',
#   'due_date': '2025-10-09T22:00:00.890026'},
#  {'order_id': 'ORD_002983_2MO1JTTE_000',
#   'item_id': '2MO1JTTE5WQPSFK',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:17.890026',
#   'due_date': '2025-10-09T16:00:00.890026'},
#  {'order_id': 'ORD_004422_2MO1JTTE_000',
#   'item_id': '2MO1JTTE5WQPSFK',
#   'quantity': 1,
#   'creation_date': '2025-10-09T02:14:42.357082',
#   'due_date': '2025-10-09T06:00:00.357082'},
#  {'order_id': 'ORD_002983_1NUZWGEF_000',
#   'item_id': '1NUZWGEFPH0KOFP',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:17.890026',
#   'due_date': '2025-10-09T22:00:00.890026'},
#  {'order_id': 'ORD_002983_R5PNOJJS_000',
#   'item_id': 'R5PNOJJS84SXNTX',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:17.890026',
#   'due_date': '2025-10-09T23:59:00.890026'},
#  {'order_id': 'ORD_002983_66R2A1LL_000',
#   'item_id': '66R2A1LL2Z84Z92',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:17.890026',
#   'due_date': '2025-10-09T10:00:00.890026'},
#  {'order_id': 'ORD_012424_66R2A1LL_000',
#   'item_id': '66R2A1LL2Z84Z92',
#   'quantity': 1,
#   'creation_date': '2025-10-09T11:10:32.117437',
#   'due_date': '2025-10-09T23:59:00.117437'},
#  {'order_id': 'ORD_012424_66R2A1LL_001',
#   'item_id': '66R2A1LL2Z84Z92',
#   'quantity': 1,
#   'creation_date': '2025-10-09T11:10:32.117437',
#   'due_date': '2025-10-09T16:00:00.117437'},
#  {'order_id': 'ORD_002983_1U8XZTZV_000',
#   'item_id': '1U8XZTZVS386C4Q',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:17.890026',
#   'due_date': '2025-10-09T23:59:00.890026'},
#  {'order_id': 'ORD_002983_N6VIHCU3_000',
#   'item_id': 'N6VIHCU3R8802HR',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:17.890026',
#   'due_date': '2025-10-09T22:00:00.890026'},
#  {'order_id': 'ORD_002983_6V9J5L9S_000',
#   'item_id': '6V9J5L9S8AHGUZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:17.890026',
#   'due_date': '2025-10-09T16:00:00.890026'},
#  {'order_id': 'ORD_002983_6V9J5L9S_001',
#   'item_id': '6V9J5L9S8AHGUZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:17.890026',
#   'due_date': '2025-10-09T21:00:00.890026'},
#  {'order_id': 'ORD_002983_6V9J5L9S_002',
#   'item_id': '6V9J5L9S8AHGUZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:17.890026',
#   'due_date': '2025-10-09T21:00:00.890026'},
#  {'order_id': 'ORD_002983_6V9J5L9S_003',
#   'item_id': '6V9J5L9S8AHGUZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:17.890026',
#   'due_date': '2025-10-09T19:00:00.890026'},
#  {'order_id': 'ORD_002208_6V9J5L9S_000',
#   'item_id': '6V9J5L9S8AHGUZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T02:14:27.900796',
#   'due_date': '2025-10-09T14:00:00.900796'},
#  {'order_id': 'ORD_005866_6V9J5L9S_000',
#   'item_id': '6V9J5L9S8AHGUZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T05:05:11.259487',
#   'due_date': '2025-10-09T19:00:00.259487'},
#  {'order_id': 'ORD_005866_6V9J5L9S_001',
#   'item_id': '6V9J5L9S8AHGUZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T05:05:11.259487',
#   'due_date': '2025-10-09T22:00:00.259487'},
#  {'order_id': 'ORD_005866_6V9J5L9S_002',
#   'item_id': '6V9J5L9S8AHGUZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T05:05:11.259487',
#   'due_date': '2025-10-09T19:00:00.259487'},
#  {'order_id': 'ORD_011979_6V9J5L9S_000',
#   'item_id': '6V9J5L9S8AHGUZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T09:36:40.425524',
#   'due_date': '2025-10-09T22:00:00.425524'},
#  {'order_id': 'ORD_011979_6V9J5L9S_001',
#   'item_id': '6V9J5L9S8AHGUZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T09:36:40.425524',
#   'due_date': '2025-10-09T21:00:00.425524'},
#  {'order_id': 'ORD_011979_6V9J5L9S_002',
#   'item_id': '6V9J5L9S8AHGUZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T09:36:40.425524',
#   'due_date': '2025-10-09T10:00:00.425524'},
#  {'order_id': 'ORD_011979_6V9J5L9S_003',
#   'item_id': '6V9J5L9S8AHGUZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T09:36:40.425524',
#   'due_date': '2025-10-09T19:00:00.425524'},
#  {'order_id': 'ORD_011979_6V9J5L9S_004',
#   'item_id': '6V9J5L9S8AHGUZY',
#   'quantity': 1,
#   'creation_date': '2025-10-09T09:36:40.425524',
#   'due_date': '2025-10-09T16:00:00.425524'},
#  {'order_id': 'ORD_010262_ZDZFO5J0_000',
#   'item_id': 'ZDZFO5J02DHHTO4',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:22.878715',
#   'due_date': '2025-10-09T22:00:00.878715'},
#  {'order_id': 'ORD_011099_LEGEXAQP_000',
#   'item_id': 'LEGEXAQPCRO1OPF',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:23.615539',
#   'due_date': '2025-10-09T10:00:00.615539'},
#  {'order_id': 'ORD_001587_LEGEXAQP_000',
#   'item_id': 'LEGEXAQPCRO1OPF',
#   'quantity': 1,
#   'creation_date': '2025-10-09T04:44:36.513083',
#   'due_date': '2025-10-09T19:00:00.513083'},
#  {'order_id': 'ORD_011099_DA776K16_000',
#   'item_id': 'DA776K16JQ53V2B',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:23.615539',
#   'due_date': '2025-10-09T06:00:00.615539'},
#  {'order_id': 'ORD_011099_DA776K16_001',
#   'item_id': 'DA776K16JQ53V2B',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:23.615539',
#   'due_date': '2025-10-09T23:59:00.615539'},
#  {'order_id': 'ORD_011099_GRR0WZXS_000',
#   'item_id': 'GRR0WZXSJITESTH',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:23.615539',
#   'due_date': '2025-10-09T19:00:00.615539'},
#  {'order_id': 'ORD_011099_X70PZWTI_000',
#   'item_id': 'X70PZWTIRRZUYJD',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:23.615539',
#   'due_date': '2025-10-09T22:00:00.615539'},
#  {'order_id': 'ORD_011099_AP93A8TC_000',
#   'item_id': 'AP93A8TCCKG2NHT',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:23.615539',
#   'due_date': '2025-10-09T16:00:00.615539'},
#  {'order_id': 'ORD_011099_AP93A8TC_001',
#   'item_id': 'AP93A8TCCKG2NHT',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:23.615539',
#   'due_date': '2025-10-09T10:00:00.615539'},
#  {'order_id': 'ORD_013865_3588XLPW_000',
#   'item_id': '3588XLPW9ISMDMO',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:26.565234',
#   'due_date': '2025-10-09T06:00:00.565234'},
#  {'order_id': 'ORD_013865_3588XLPW_001',
#   'item_id': '3588XLPW9ISMDMO',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:26.565234',
#   'due_date': '2025-10-09T23:59:00.565234'},
#  {'order_id': 'ORD_013865_3588XLPW_002',
#   'item_id': '3588XLPW9ISMDMO',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:26.565234',
#   'due_date': '2025-10-09T10:00:00.565234'},
#  {'order_id': 'ORD_013865_OKTAKVB4_000',
#   'item_id': 'OKTAKVB44OVEIZQ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:26.565234',
#   'due_date': '2025-10-09T21:00:00.565234'},
#  {'order_id': 'ORD_013865_OKTAKVB4_001',
#   'item_id': 'OKTAKVB44OVEIZQ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:26.565234',
#   'due_date': '2025-10-09T21:00:00.565234'},
#  {'order_id': 'ORD_013865_OKTAKVB4_002',
#   'item_id': 'OKTAKVB44OVEIZQ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:26.565234',
#   'due_date': '2025-10-09T23:59:00.565234'},
#  {'order_id': 'ORD_013865_OKTAKVB4_003',
#   'item_id': 'OKTAKVB44OVEIZQ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:26.565234',
#   'due_date': '2025-10-09T16:00:00.565234'},
#  {'order_id': 'ORD_013865_OKTAKVB4_004',
#   'item_id': 'OKTAKVB44OVEIZQ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:26.565234',
#   'due_date': '2025-10-09T21:00:00.565234'},
#  {'order_id': 'ORD_013054_OKTAKVB4_000',
#   'item_id': 'OKTAKVB44OVEIZQ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T02:03:43.566970',
#   'due_date': '2025-10-09T23:59:00.566970'},
#  {'order_id': 'ORD_013865_8DGSFHMU_000',
#   'item_id': '8DGSFHMU4YE1XNU',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:26.565234',
#   'due_date': '2025-10-09T10:00:00.565234'},
#  {'order_id': 'ORD_013865_KOY0RB4V_000',
#   'item_id': 'KOY0RB4VYFFDB4D',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:26.565234',
#   'due_date': '2025-10-09T06:00:00.565234'},
#  {'order_id': 'ORD_013865_KOY0RB4V_001',
#   'item_id': 'KOY0RB4VYFFDB4D',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:26.565234',
#   'due_date': '2025-10-09T16:00:00.565234'},
#  {'order_id': 'ORD_013865_KOY0RB4V_002',
#   'item_id': 'KOY0RB4VYFFDB4D',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:26.565234',
#   'due_date': '2025-10-09T16:00:00.565234'},
#  {'order_id': 'ORD_013865_KOY0RB4V_003',
#   'item_id': 'KOY0RB4VYFFDB4D',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:26.565234',
#   'due_date': '2025-10-09T23:59:00.565234'},
#  {'order_id': 'ORD_013865_KOY0RB4V_004',
#   'item_id': 'KOY0RB4VYFFDB4D',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:26.565234',
#   'due_date': '2025-10-09T06:00:00.565234'},
#  {'order_id': 'ORD_011577_XZUWDQCH_000',
#   'item_id': 'XZUWDQCHDASBDYZ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:28.187393',
#   'due_date': '2025-10-09T14:00:00.187393'},
#  {'order_id': 'ORD_011577_XZUWDQCH_001',
#   'item_id': 'XZUWDQCHDASBDYZ',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:28.187393',
#   'due_date': '2025-10-09T16:00:00.187393'},
#  {'order_id': 'ORD_011577_O8Z6PW3L_000',
#   'item_id': 'O8Z6PW3LXSN0TZC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:28.187393',
#   'due_date': '2025-10-09T23:59:00.187393'},
#  {'order_id': 'ORD_011577_O8Z6PW3L_001',
#   'item_id': 'O8Z6PW3LXSN0TZC',
#   'quantity': 1,
#   'creation_date': '2025-10-09T00:03:28.187393',
#   'due_date': '2025-10-09T22:00:00.187393'},
#  ...]

# %%
backlog_total = backlog_preprocesado
resultados = []
CANT_CICLOS = 288
cant_racks = int(list(stock.keys())[-1].split('_')[1])
racks_tibios = [0] * cant_racks
fecha_inicial = datetime(2025, 10, 9, 0, 0, 0)
suma_ordenes_cumplidas = 0
costo_final = 0
ordenes_restantes = len(backlog_preprocesado)
costos_promedios = []
inicio_total = time.time()

backlog_final = {"orders": []} # en este backlog se van guardando las ordenes ya creadas y listas para ser cumplidas

np.random.seed(42)

caras_totales = []
racks_totales = set()
caras_sobre_racks = []

for ciclo in range(1, CANT_CICLOS + 1):
    hora_actual = fecha_inicial + timedelta(minutes=5 * ciclo)
    print(f"\n Ciclo {ciclo} - Hora simulada: {hora_actual.strftime('%H:%M')}")

    ordenes_disponibles = [
    o for o in backlog_total
    if (datetime.fromisoformat(o["creation_date"]) <= hora_actual and datetime.fromisoformat(o["creation_date"])> hora_actual - timedelta(minutes=5))
    ] # me guardo las ordenes que fueron creadas en los ultimos 5 minutos

    ids_actuales = {o["order_id"] for o in backlog_final["orders"]}
    nuevas_ordenes = [o for o in ordenes_disponibles if o["order_id"] not in ids_actuales]

    if nuevas_ordenes:
        backlog_final["orders"].extend(nuevas_ordenes)

    numero = random.randint(1000, 2000)
    N = min(len(backlog_final["orders"]), numero)

    cant_pendientes = random.randint(0, 100)

    pendientes = random.sample(backlog_final["orders"], min(cant_pendientes, len(backlog_final["orders"])))
    pendientes_ids = {p["order_id"] for p in pendientes}
    backlog_final["orders"] = [orden for orden in backlog_final["orders"] if orden["order_id"] not in pendientes_ids]


    print(f"Preparando ejecución... N={N}, Pendientes={len(pendientes)}")


    try:
        resultado, costo_total = SS(stock,pendientes, N, racks_tibios, cant_racks, hora_actual)

        if len(resultado) > 0:
          caras_usadas = len(resultado)  # (rack, cara)
          ppf = N/caras_usadas

          racks_usados = set()
          for res in resultado:
            racks_usados.add(res[0])

          caras_totales.append(len(resultado))
          cant_racks_usados = len(list(racks_usados))
          caras_sobre_racks.append(len(resultado)/cant_racks_usados)

        else:
          ppf = 0

        racks_totales = racks_totales.union(racks_usados)


        print(f"Ciclo {ciclo} OK → {N} tareas | Costo total: {costo_total:.0f} | PPF: {ppf:.2f}")

        resultados.append({
            "ciclo": ciclo,
            "hora": hora_actual.strftime("%H:%M"),
            "tareas": N,
            "costo": costo_total,
            "ppf": ppf,
            "pendientes": len(pendientes),
            "ordenes_restantes": ordenes_restantes,
            "costo_por_paquete" : costo_total / N
        })

        suma_ordenes_cumplidas += N
        costo_final += costo_total
        ordenes_restantes -= N
        print(f"Ordenes restantes: {ordenes_restantes}")
    except Exception as e:
        print(f" Error en ciclo {ciclo}: {type(e).__name__} → {e}")
        break



# === Calcular promedio diario de PPF ===
ppf_valores = [r["ppf"] for r in resultados if r["ppf"] > 0]
if len(ppf_valores) > 0:
    promedio_ppf = sum(ppf_valores) / len(ppf_valores)
else:
    promedio_ppf = 0

# === Calcular promedios de costo por paquete para cada ciclo ===
promedios_valores = [r['costo_por_paquete'] for r in resultados]

fin_total = time.time()
tiempo_total = fin_total - inicio_total
tiempo_promedio_por_ciclo = tiempo_total / CANT_CICLOS
costo_prom_por_orden = costo_final / suma_ordenes_cumplidas
tasa_racks_utilizados = (len(list(racks_totales)) / cant_racks)*100
#tasa_caras_utilizados = (total_caras_usadas / cant_caras)
tasa_cumplimiento_SLA = ((suma_ordenes_cumplidas-cant_ordenes_vencidas) / suma_ordenes_cumplidas) * 100

print(f"\n Ordenes totales cumplidas: {suma_ordenes_cumplidas}")
print(f"\n Costo final: {costo_final}")
print(f"\n Promedio de costo por paquete por ciclo: {promedios_valores}")
print(f"\n Racks únicos utilizados: {cant_racks_usados}({tasa_racks_utilizados:.2f}%)")
print(f"\n Promedio de cantidad de caras usadas en un ciclo: {sum(caras_totales)/len(caras_totales):.2f}")
print(f"\n Promedio caras usadas por racks usados: {np.mean(caras_sobre_racks):.2f}")
print(f"\n Promedio diario de Picks per Face: {promedio_ppf:.2f}")
print(f"\n Costo promedio por orden: {costo_prom_por_orden:.2f}")
print(f"\n Tasa de cumplimiento SLA: {tasa_cumplimiento_SLA}%")
print(f"\n Tiempo promedio de ejecución por ciclo: {tiempo_promedio_por_ciclo:.2f} segundos")
# Out:
#  Ciclo 1 - Hora simulada: 00:05
# Preparando ejecución... N=962, Pendientes=58
# Ciclo 1 OK → 962 tareas | Costo total: 2467 | PPF: 1.75
# Ordenes restantes: 170784
#
#  Ciclo 2 - Hora simulada: 00:10
# Preparando ejecución... N=1088, Pendientes=20
# Ciclo 2 OK → 1088 tareas | Costo total: 2414 | PPF: 1.81
# Ordenes restantes: 169696
#
#  Ciclo 3 - Hora simulada: 00:15
# Preparando ejecución... N=762, Pendientes=55
# Ciclo 3 OK → 762 tareas | Costo total: 1784 | PPF: 1.77
# Ordenes restantes: 168934
#
#  Ciclo 4 - Hora simulada: 00:20
# Preparando ejecución... N=759, Pendientes=56
# Ciclo 4 OK → 759 tareas | Costo total: 1740 | PPF: 1.82
# Ordenes restantes: 168175
#
#  Ciclo 5 - Hora simulada: 00:25
# Preparando ejecución... N=928, Pendientes=38
# Ciclo 5 OK → 928 tareas | Costo total: 1918 | PPF: 1.99
# Ordenes restantes: 167247
#
#  Ciclo 6 - Hora simulada: 00:30
# Preparando ejecución... N=781, Pendientes=48
# Ciclo 6 OK → 781 tareas | Costo total: 1866 | PPF: 1.71
# Ordenes restantes: 166466
#
#  Ciclo 7 - Hora simulada: 00:35
# Preparando ejecución... N=825, Pendientes=18
# Ciclo 7 OK → 825 tareas | Costo total: 1889 | PPF: 1.78
# Ordenes restantes: 165641
#
#  Ciclo 8 - Hora simulada: 00:40
# Preparando ejecución... N=893, Pendientes=100
# Ciclo 8 OK → 893 tareas | Costo total: 1978 | PPF: 1.85
# Ordenes restantes: 164748
#
#  Ciclo 9 - Hora simulada: 00:45
# Preparando ejecución... N=911, Pendientes=7
# Ciclo 9 OK → 911 tareas | Costo total: 1962 | PPF: 1.91
# Ordenes restantes: 163837
#
#  Ciclo 10 - Hora simulada: 00:50
# Preparando ejecución... N=737, Pendientes=32
# Ciclo 10 OK → 737 tareas | Costo total: 1671 | PPF: 1.84
# Ordenes restantes: 163100
#
#  Ciclo 11 - Hora simulada: 00:55
# Preparando ejecución... N=795, Pendientes=9
# Ciclo 11 OK → 795 tareas | Costo total: 1804 | PPF: 1.82
# Ordenes restantes: 162305
#
#  Ciclo 12 - Hora simulada: 01:00
# Preparando ejecución... N=908, Pendientes=36
# Ciclo 12 OK → 908 tareas | Costo total: 2027 | PPF: 1.88
# Ordenes restantes: 161397
#
#  Ciclo 13 - Hora simulada: 01:05
# Preparando ejecución... N=833, Pendientes=76
# Ciclo 13 OK → 833 tareas | Costo total: 1863 | PPF: 1.83
# Ordenes restantes: 160564
#
#  Ciclo 14 - Hora simulada: 01:10
# Preparando ejecución... N=1091, Pendientes=1
# Ciclo 14 OK → 1091 tareas | Costo total: 2408 | PPF: 1.86
# Ordenes restantes: 159473
#
#  Ciclo 15 - Hora simulada: 01:15
# Preparando ejecución... N=958, Pendientes=91
# Ciclo 15 OK → 958 tareas | Costo total: 2117 | PPF: 1.82
# Ordenes restantes: 158515
#
#  Ciclo 16 - Hora simulada: 01:20
# Preparando ejecución... N=940, Pendientes=54
# Ciclo 16 OK → 940 tareas | Costo total: 1998 | PPF: 1.93
# Ordenes restantes: 157575
#
#  Ciclo 17 - Hora simulada: 01:25
# Preparando ejecución... N=799, Pendientes=44
# Ciclo 17 OK → 799 tareas | Costo total: 1861 | PPF: 1.81
# Ordenes restantes: 156776
#
#  Ciclo 18 - Hora simulada: 01:30
# Preparando ejecución... N=879, Pendientes=62
# Ciclo 18 OK → 879 tareas | Costo total: 1859 | PPF: 1.96
# Ordenes restantes: 155897
#
#  Ciclo 19 - Hora simulada: 01:35
# Preparando ejecución... N=822, Pendientes=93
# Ciclo 19 OK → 822 tareas | Costo total: 1830 | PPF: 1.85
# Ordenes restantes: 155075
#
#  Ciclo 20 - Hora simulada: 01:40
# Preparando ejecución... N=841, Pendientes=100
# Ciclo 20 OK → 841 tareas | Costo total: 1842 | PPF: 1.89
# Ordenes restantes: 154234
#
#  Ciclo 21 - Hora simulada: 01:45
# Preparando ejecución... N=826, Pendientes=47
# Ciclo 21 OK → 826 tareas | Costo total: 1983 | PPF: 1.73
# Ordenes restantes: 153408
#
#  Ciclo 22 - Hora simulada: 01:50
# Preparando ejecución... N=780, Pendientes=94
# Ciclo 22 OK → 780 tareas | Costo total: 1730 | PPF: 1.88
# Ordenes restantes: 152628
#
#  Ciclo 23 - Hora simulada: 01:55
# Preparando ejecución... N=958, Pendientes=15
# Ciclo 23 OK → 958 tareas | Costo total: 2085 | PPF: 1.93
# Ordenes restantes: 151670
#
#  Ciclo 24 - Hora simulada: 02:00
# Preparando ejecución... N=934, Pendientes=62
# Ciclo 24 OK → 934 tareas | Costo total: 2015 | PPF: 1.89
# Ordenes restantes: 150736
#
#  Ciclo 25 - Hora simulada: 02:05
# Preparando ejecución... N=785, Pendientes=71
# Ciclo 25 OK → 785 tareas | Costo total: 1887 | PPF: 1.71
# Ordenes restantes: 149951
#
#  Ciclo 26 - Hora simulada: 02:10
# Preparando ejecución... N=766, Pendientes=79
# Ciclo 26 OK → 766 tareas | Costo total: 1760 | PPF: 1.85
# Ordenes restantes: 149185
#
#  Ciclo 27 - Hora simulada: 02:15
# Preparando ejecución... N=929, Pendientes=58
# Ciclo 27 OK → 929 tareas | Costo total: 2107 | PPF: 1.83
# Ordenes restantes: 148256
#
#  Ciclo 28 - Hora simulada: 02:20
# Preparando ejecución... N=722, Pendientes=89
# Ciclo 28 OK → 722 tareas | Costo total: 1746 | PPF: 1.74
# Ordenes restantes: 147534
#
#  Ciclo 29 - Hora simulada: 02:25
# Preparando ejecución... N=642, Pendientes=98
# Ciclo 29 OK → 642 tareas | Costo total: 1555 | PPF: 1.74
# Ordenes restantes: 146892
#
#  Ciclo 30 - Hora simulada: 02:30
# Preparando ejecución... N=703, Pendientes=97
# Ciclo 30 OK → 703 tareas | Costo total: 1551 | PPF: 1.92
# Ordenes restantes: 146189
#
#  Ciclo 31 - Hora simulada: 02:35
# Preparando ejecución... N=831, Pendientes=17
# Ciclo 31 OK → 831 tareas | Costo total: 1894 | PPF: 1.83
# Ordenes restantes: 145358
#
#  Ciclo 32 - Hora simulada: 02:40
# Preparando ejecución... N=822, Pendientes=97
# Ciclo 32 OK → 822 tareas | Costo total: 1828 | PPF: 1.84
# Ordenes restantes: 144536
#
#  Ciclo 33 - Hora simulada: 02:45
# Preparando ejecución... N=741, Pendientes=97
# Ciclo 33 OK → 741 tareas | Costo total: 1671 | PPF: 1.87
# Ordenes restantes: 143795
#
#  Ciclo 34 - Hora simulada: 02:50
# Preparando ejecución... N=625, Pendientes=15
# Ciclo 34 OK → 625 tareas | Costo total: 1432 | PPF: 1.85
# Ordenes restantes: 143170
#
#  Ciclo 35 - Hora simulada: 02:55
# Preparando ejecución... N=915, Pendientes=55
# Ciclo 35 OK → 915 tareas | Costo total: 2085 | PPF: 1.82
# Ordenes restantes: 142255
#
#  Ciclo 36 - Hora simulada: 03:00
# Preparando ejecución... N=715, Pendientes=36
# Ciclo 36 OK → 715 tareas | Costo total: 1671 | PPF: 1.79
# Ordenes restantes: 141540
#
#  Ciclo 37 - Hora simulada: 03:05
# Preparando ejecución... N=826, Pendientes=61
# Ciclo 37 OK → 826 tareas | Costo total: 1816 | PPF: 1.93
# Ordenes restantes: 140714
#
#  Ciclo 38 - Hora simulada: 03:10
# Preparando ejecución... N=906, Pendientes=74
# Ciclo 38 OK → 906 tareas | Costo total: 1970 | PPF: 1.87
# Ordenes restantes: 139808
#
#  Ciclo 39 - Hora simulada: 03:15
# Preparando ejecución... N=820, Pendientes=1
# Ciclo 39 OK → 820 tareas | Costo total: 1817 | PPF: 1.90
# Ordenes restantes: 138988
#
#  Ciclo 40 - Hora simulada: 03:20
# Preparando ejecución... N=895, Pendientes=97
# Ciclo 40 OK → 895 tareas | Costo total: 1915 | PPF: 1.95
# Ordenes restantes: 138093
#
#  Ciclo 41 - Hora simulada: 03:25
# Preparando ejecución... N=782, Pendientes=69
# Ciclo 41 OK → 782 tareas | Costo total: 1802 | PPF: 1.79
# Ordenes restantes: 137311
#
#  Ciclo 42 - Hora simulada: 03:30
# Preparando ejecución... N=838, Pendientes=76
# Ciclo 42 OK → 838 tareas | Costo total: 1907 | PPF: 1.81
# Ordenes restantes: 136473
#
#  Ciclo 43 - Hora simulada: 03:35
# Preparando ejecución... N=866, Pendientes=74
# Ciclo 43 OK → 866 tareas | Costo total: 1958 | PPF: 1.88
# Ordenes restantes: 135607
#
#  Ciclo 44 - Hora simulada: 03:40
# Preparando ejecución... N=907, Pendientes=42
# Ciclo 44 OK → 907 tareas | Costo total: 2009 | PPF: 1.89
# Ordenes restantes: 134700
#
#  Ciclo 45 - Hora simulada: 03:45
# Preparando ejecución... N=827, Pendientes=73
# Ciclo 45 OK → 827 tareas | Costo total: 1777 | PPF: 1.91
# Ordenes restantes: 133873
#
#  Ciclo 46 - Hora simulada: 03:50
# Preparando ejecución... N=633, Pendientes=18
# Ciclo 46 OK → 633 tareas | Costo total: 1426 | PPF: 1.87
# Ordenes restantes: 133240
#
#  Ciclo 47 - Hora simulada: 03:55
# Preparando ejecución... N=628, Pendientes=1
# Ciclo 47 OK → 628 tareas | Costo total: 1447 | PPF: 1.79
# Ordenes restantes: 132612
#
#  Ciclo 48 - Hora simulada: 04:00
# Preparando ejecución... N=742, Pendientes=43
# Ciclo 48 OK → 742 tareas | Costo total: 1725 | PPF: 1.78
# Ordenes restantes: 131870
#
#  Ciclo 49 - Hora simulada: 04:05
# Preparando ejecución... N=695, Pendientes=4
# Ciclo 49 OK → 695 tareas | Costo total: 1574 | PPF: 1.80
# Ordenes restantes: 131175
#
#  Ciclo 50 - Hora simulada: 04:10
# Preparando ejecución... N=719, Pendientes=45
# Ciclo 50 OK → 719 tareas | Costo total: 1679 | PPF: 1.74
# Ordenes restantes: 130456
#
#  Ciclo 51 - Hora simulada: 04:15
# Preparando ejecución... N=778, Pendientes=50
# Ciclo 51 OK → 778 tareas | Costo total: 1661 | PPF: 1.93
# Ordenes restantes: 129678
#
#  Ciclo 52 - Hora simulada: 04:20
# Preparando ejecución... N=793, Pendientes=95
# Ciclo 52 OK → 793 tareas | Costo total: 1836 | PPF: 1.77
# Ordenes restantes: 128885
#
#  Ciclo 53 - Hora simulada: 04:25
# Preparando ejecución... N=814, Pendientes=64
# Ciclo 53 OK → 814 tareas | Costo total: 1761 | PPF: 1.90
# Ordenes restantes: 128071
#
#  Ciclo 54 - Hora simulada: 04:30
# Preparando ejecución... N=746, Pendientes=2
# Ciclo 54 OK → 746 tareas | Costo total: 1734 | PPF: 1.82
# Ordenes restantes: 127325
#
#  Ciclo 55 - Hora simulada: 04:35
# Preparando ejecución... N=647, Pendientes=62
# Ciclo 55 OK → 647 tareas | Costo total: 1485 | PPF: 1.81
# Ordenes restantes: 126678
#
#  Ciclo 56 - Hora simulada: 04:40
# Preparando ejecución... N=582, Pendientes=17
# Ciclo 56 OK → 582 tareas | Costo total: 1388 | PPF: 1.80
# Ordenes restantes: 126096
#
#  Ciclo 57 - Hora simulada: 04:45
# Preparando ejecución... N=819, Pendientes=89
# Ciclo 57 OK → 819 tareas | Costo total: 1897 | PPF: 1.79
# Ordenes restantes: 125277
#
#  Ciclo 58 - Hora simulada: 04:50
# Preparando ejecución... N=655, Pendientes=11
# Ciclo 58 OK → 655 tareas | Costo total: 1554 | PPF: 1.76
# Ordenes restantes: 124622
#
#  Ciclo 59 - Hora simulada: 04:55
# Preparando ejecución... N=774, Pendientes=62
# Ciclo 59 OK → 774 tareas | Costo total: 1766 | PPF: 1.81
# Ordenes restantes: 123848
#
#  Ciclo 60 - Hora simulada: 05:00
# Preparando ejecución... N=908, Pendientes=64
# Ciclo 60 OK → 908 tareas | Costo total: 2001 | PPF: 1.86
# Ordenes restantes: 122940
#
#  Ciclo 61 - Hora simulada: 05:05
# Preparando ejecución... N=652, Pendientes=35
# Ciclo 61 OK → 652 tareas | Costo total: 1566 | PPF: 1.78
# Ordenes restantes: 122288
#
#  Ciclo 62 - Hora simulada: 05:10
# Preparando ejecución... N=768, Pendientes=70
# Ciclo 62 OK → 768 tareas | Costo total: 1698 | PPF: 1.90
# Ordenes restantes: 121520
#
#  Ciclo 63 - Hora simulada: 05:15
# Preparando ejecución... N=875, Pendientes=85
# Ciclo 63 OK → 875 tareas | Costo total: 1854 | PPF: 1.94
# Ordenes restantes: 120645
#
#  Ciclo 64 - Hora simulada: 05:20
# Preparando ejecución... N=766, Pendientes=100
# Ciclo 64 OK → 766 tareas | Costo total: 1650 | PPF: 1.87
# Ordenes restantes: 119879
#
#  Ciclo 65 - Hora simulada: 05:25
# Preparando ejecución... N=897, Pendientes=92
# Ciclo 65 OK → 897 tareas | Costo total: 2044 | PPF: 1.87
# Ordenes restantes: 118982
#
#  Ciclo 66 - Hora simulada: 05:30
# Preparando ejecución... N=605, Pendientes=24
# Ciclo 66 OK → 605 tareas | Costo total: 1435 | PPF: 1.80
# Ordenes restantes: 118377
#
#  Ciclo 67 - Hora simulada: 05:35
# Preparando ejecución... N=711, Pendientes=64
# Ciclo 67 OK → 711 tareas | Costo total: 1578 | PPF: 1.90
# Ordenes restantes: 117666
#
#  Ciclo 68 - Hora simulada: 05:40
# Preparando ejecución... N=726, Pendientes=77
# Ciclo 68 OK → 726 tareas | Costo total: 1564 | PPF: 1.96
# Ordenes restantes: 116940
#
#  Ciclo 69 - Hora simulada: 05:45
# Preparando ejecución... N=820, Pendientes=77
# Ciclo 69 OK → 820 tareas | Costo total: 1830 | PPF: 1.92
# Ordenes restantes: 116120
#
#  Ciclo 70 - Hora simulada: 05:50
# Preparando ejecución... N=776, Pendientes=93
# Ciclo 70 OK → 776 tareas | Costo total: 1832 | PPF: 1.79
# Ordenes restantes: 115344
#
#  Ciclo 71 - Hora simulada: 05:55
# Preparando ejecución... N=724, Pendientes=84
# Ciclo 71 OK → 724 tareas | Costo total: 1739 | PPF: 1.78
# Ordenes restantes: 114620
#
#  Ciclo 72 - Hora simulada: 06:00
# Preparando ejecución... N=583, Pendientes=87
# Ciclo 72 OK → 583 tareas | Costo total: 1273 | PPF: 1.91
# Ordenes restantes: 114037
#
#  Ciclo 73 - Hora simulada: 06:05
# Preparando ejecución... N=702, Pendientes=90
# Ciclo 73 OK → 702 tareas | Costo total: 1499 | PPF: 1.93
# Ordenes restantes: 113335
#
#  Ciclo 74 - Hora simulada: 06:10
# Preparando ejecución... N=764, Pendientes=45
# Ciclo 74 OK → 764 tareas | Costo total: 1844 | PPF: 1.76
# Ordenes restantes: 112571
#
#  Ciclo 75 - Hora simulada: 06:15
# Preparando ejecución... N=696, Pendientes=43
# Ciclo 75 OK → 696 tareas | Costo total: 1610 | PPF: 1.83
# Ordenes restantes: 111875
#
#  Ciclo 76 - Hora simulada: 06:20
# Preparando ejecución... N=838, Pendientes=46
# Ciclo 76 OK → 838 tareas | Costo total: 1838 | PPF: 1.91
# Ordenes restantes: 111037
#
#  Ciclo 77 - Hora simulada: 06:25
# Preparando ejecución... N=781, Pendientes=63
# Ciclo 77 OK → 781 tareas | Costo total: 1781 | PPF: 1.80
# Ordenes restantes: 110256
#
#  Ciclo 78 - Hora simulada: 06:30
# Preparando ejecución... N=659, Pendientes=27
# Ciclo 78 OK → 659 tareas | Costo total: 1566 | PPF: 1.79
# Ordenes restantes: 109597
#
#  Ciclo 79 - Hora simulada: 06:35
# Preparando ejecución... N=681, Pendientes=20
# Ciclo 79 OK → 681 tareas | Costo total: 1678 | PPF: 1.72
# Ordenes restantes: 108916
#
#  Ciclo 80 - Hora simulada: 06:40
# Preparando ejecución... N=585, Pendientes=50
# Ciclo 80 OK → 585 tareas | Costo total: 1310 | PPF: 1.91
# Ordenes restantes: 108331
#
#  Ciclo 81 - Hora simulada: 06:45
# Preparando ejecución... N=604, Pendientes=0
# Ciclo 81 OK → 604 tareas | Costo total: 1386 | PPF: 1.83
# Ordenes restantes: 107727
#
#  Ciclo 82 - Hora simulada: 06:50
# Preparando ejecución... N=601, Pendientes=25
# Ciclo 82 OK → 601 tareas | Costo total: 1383 | PPF: 1.83
# Ordenes restantes: 107126
#
#  Ciclo 83 - Hora simulada: 06:55
# Preparando ejecución... N=753, Pendientes=39
# Ciclo 83 OK → 753 tareas | Costo total: 1771 | PPF: 1.82
# Ordenes restantes: 106373
#
#  Ciclo 84 - Hora simulada: 07:00
# Preparando ejecución... N=716, Pendientes=94
# Ciclo 84 OK → 716 tareas | Costo total: 1515 | PPF: 1.94
# Ordenes restantes: 105657
#
#  Ciclo 85 - Hora simulada: 07:05
# Preparando ejecución... N=602, Pendientes=58
# Ciclo 85 OK → 602 tareas | Costo total: 1396 | PPF: 1.88
# Ordenes restantes: 105055
#
#  Ciclo 86 - Hora simulada: 07:10
# Preparando ejecución... N=653, Pendientes=98
# Ciclo 86 OK → 653 tareas | Costo total: 1542 | PPF: 1.82
# Ordenes restantes: 104402
#
#  Ciclo 87 - Hora simulada: 07:15
# Preparando ejecución... N=580, Pendientes=14
# Ciclo 87 OK → 580 tareas | Costo total: 1344 | PPF: 1.81
# Ordenes restantes: 103822
#
#  Ciclo 88 - Hora simulada: 07:20
# Preparando ejecución... N=693, Pendientes=62
# Ciclo 88 OK → 693 tareas | Costo total: 1531 | PPF: 1.89
# Ordenes restantes: 103129
#
#  Ciclo 89 - Hora simulada: 07:25
# Preparando ejecución... N=732, Pendientes=90
# Ciclo 89 OK → 732 tareas | Costo total: 1678 | PPF: 1.81
# Ordenes restantes: 102397
#
#  Ciclo 90 - Hora simulada: 07:30
# Preparando ejecución... N=705, Pendientes=16
# Ciclo 90 OK → 705 tareas | Costo total: 1633 | PPF: 1.82
# Ordenes restantes: 101692
#
#  Ciclo 91 - Hora simulada: 07:35
# Preparando ejecución... N=581, Pendientes=27
# Ciclo 91 OK → 581 tareas | Costo total: 1293 | PPF: 1.90
# Ordenes restantes: 101111
#
#  Ciclo 92 - Hora simulada: 07:40
# Preparando ejecución... N=643, Pendientes=52
# Ciclo 92 OK → 643 tareas | Costo total: 1518 | PPF: 1.81
# Ordenes restantes: 100468
#
#  Ciclo 93 - Hora simulada: 07:45
# Preparando ejecución... N=681, Pendientes=30
# Ciclo 93 OK → 681 tareas | Costo total: 1513 | PPF: 1.91
# Ordenes restantes: 99787
#
#  Ciclo 94 - Hora simulada: 07:50
# Preparando ejecución... N=645, Pendientes=44
# Ciclo 94 OK → 645 tareas | Costo total: 1503 | PPF: 1.78
# Ordenes restantes: 99142
#
#  Ciclo 95 - Hora simulada: 07:55
# Preparando ejecución... N=706, Pendientes=22
# Ciclo 95 OK → 706 tareas | Costo total: 1578 | PPF: 1.84
# Ordenes restantes: 98436
#
#  Ciclo 96 - Hora simulada: 08:00
# Preparando ejecución... N=685, Pendientes=41
# Ciclo 96 OK → 685 tareas | Costo total: 1623 | PPF: 1.80
# Ordenes restantes: 97751
#
#  Ciclo 97 - Hora simulada: 08:05
# Preparando ejecución... N=608, Pendientes=64
# Ciclo 97 OK → 608 tareas | Costo total: 1416 | PPF: 1.77
# Ordenes restantes: 97143
#
#  Ciclo 98 - Hora simulada: 08:10
# Preparando ejecución... N=585, Pendientes=91
# Ciclo 98 OK → 585 tareas | Costo total: 1304 | PPF: 1.89
# Ordenes restantes: 96558
#
#  Ciclo 99 - Hora simulada: 08:15
# Preparando ejecución... N=745, Pendientes=48
# Ciclo 99 OK → 745 tareas | Costo total: 1559 | PPF: 1.97
# Ordenes restantes: 95813
#
#  Ciclo 100 - Hora simulada: 08:20
# Preparando ejecución... N=681, Pendientes=97
# Ciclo 100 OK → 681 tareas | Costo total: 1570 | PPF: 1.80
# Ordenes restantes: 95132
#
#  Ciclo 101 - Hora simulada: 08:25
# Preparando ejecución... N=580, Pendientes=20
# Ciclo 101 OK → 580 tareas | Costo total: 1249 | PPF: 1.95
# Ordenes restantes: 94552
#
#  Ciclo 102 - Hora simulada: 08:30
# Preparando ejecución... N=655, Pendientes=22
# Ciclo 102 OK → 655 tareas | Costo total: 1464 | PPF: 1.85
# Ordenes restantes: 93897
#
#  Ciclo 103 - Hora simulada: 08:35
# Preparando ejecución... N=544, Pendientes=91
# Ciclo 103 OK → 544 tareas | Costo total: 1362 | PPF: 1.74
# Ordenes restantes: 93353
#
#  Ciclo 104 - Hora simulada: 08:40
# Preparando ejecución... N=714, Pendientes=2
# Ciclo 104 OK → 714 tareas | Costo total: 1506 | PPF: 1.91
# Ordenes restantes: 92639
#
#  Ciclo 105 - Hora simulada: 08:45
# Preparando ejecución... N=637, Pendientes=10
# Ciclo 105 OK → 637 tareas | Costo total: 1386 | PPF: 1.88
# Ordenes restantes: 92002
#
#  Ciclo 106 - Hora simulada: 08:50
# Preparando ejecución... N=649, Pendientes=40
# Ciclo 106 OK → 649 tareas | Costo total: 1451 | PPF: 1.89
# Ordenes restantes: 91353
#
#  Ciclo 107 - Hora simulada: 08:55
# Preparando ejecución... N=696, Pendientes=50
# Ciclo 107 OK → 696 tareas | Costo total: 1563 | PPF: 1.92
# Ordenes restantes: 90657
#
#  Ciclo 108 - Hora simulada: 09:00
# Preparando ejecución... N=620, Pendientes=85
# Ciclo 108 OK → 620 tareas | Costo total: 1348 | PPF: 1.94
# Ordenes restantes: 90037
#
#  Ciclo 109 - Hora simulada: 09:05
# Preparando ejecución... N=614, Pendientes=47
# Ciclo 109 OK → 614 tareas | Costo total: 1413 | PPF: 1.83
# Ordenes restantes: 89423
#
#  Ciclo 110 - Hora simulada: 09:10
# Preparando ejecución... N=633, Pendientes=86
# Ciclo 110 OK → 633 tareas | Costo total: 1348 | PPF: 1.99
# Ordenes restantes: 88790
#
#  Ciclo 111 - Hora simulada: 09:15
# Preparando ejecución... N=626, Pendientes=22
# Ciclo 111 OK → 626 tareas | Costo total: 1428 | PPF: 1.90
# Ordenes restantes: 88164
#
#  Ciclo 112 - Hora simulada: 09:20
# Preparando ejecución... N=703, Pendientes=87
# Ciclo 112 OK → 703 tareas | Costo total: 1553 | PPF: 1.88
# Ordenes restantes: 87461
#
#  Ciclo 113 - Hora simulada: 09:25
# Preparando ejecución... N=677, Pendientes=88
# Ciclo 113 OK → 677 tareas | Costo total: 1477 | PPF: 1.94
# Ordenes restantes: 86784
#
#  Ciclo 114 - Hora simulada: 09:30
# Preparando ejecución... N=743, Pendientes=21
# Ciclo 114 OK → 743 tareas | Costo total: 1664 | PPF: 1.88
# Ordenes restantes: 86041
#
#  Ciclo 115 - Hora simulada: 09:35
# Preparando ejecución... N=803, Pendientes=40
# Ciclo 115 OK → 803 tareas | Costo total: 1753 | PPF: 1.92
# Ordenes restantes: 85238
#
#  Ciclo 116 - Hora simulada: 09:40
# Preparando ejecución... N=683, Pendientes=98
# Ciclo 116 OK → 683 tareas | Costo total: 1579 | PPF: 1.88
# Ordenes restantes: 84555
#
#  Ciclo 117 - Hora simulada: 09:45
# Preparando ejecución... N=543, Pendientes=17
# Ciclo 117 OK → 543 tareas | Costo total: 1275 | PPF: 1.77
# Ordenes restantes: 84012
#
#  Ciclo 118 - Hora simulada: 09:50
# Preparando ejecución... N=594, Pendientes=58
# Ciclo 118 OK → 594 tareas | Costo total: 1320 | PPF: 1.89
# Ordenes restantes: 83418
#
#  Ciclo 119 - Hora simulada: 09:55
# Preparando ejecución... N=806, Pendientes=19
# Ciclo 119 OK → 806 tareas | Costo total: 1724 | PPF: 1.93
# Ordenes restantes: 82612
#
#  Ciclo 120 - Hora simulada: 10:00
# Preparando ejecución... N=542, Pendientes=94
# Ciclo 120 OK → 542 tareas | Costo total: 1231 | PPF: 1.92
# Ordenes restantes: 82070
#
#  Ciclo 121 - Hora simulada: 10:05
# Preparando ejecución... N=511, Pendientes=53
# Ciclo 121 OK → 511 tareas | Costo total: 1229 | PPF: 1.73
# Ordenes restantes: 81559
#
#  Ciclo 122 - Hora simulada: 10:10
# Preparando ejecución... N=731, Pendientes=94
# Ciclo 122 OK → 731 tareas | Costo total: 1604 | PPF: 1.94
# Ordenes restantes: 80828
#
#  Ciclo 123 - Hora simulada: 10:15
# Preparando ejecución... N=538, Pendientes=10
# Ciclo 123 OK → 538 tareas | Costo total: 1137 | PPF: 2.03
# Ordenes restantes: 80290
#
#  Ciclo 124 - Hora simulada: 10:20
# Preparando ejecución... N=561, Pendientes=74
# Ciclo 124 OK → 561 tareas | Costo total: 1229 | PPF: 1.86
# Ordenes restantes: 79729
#
#  Ciclo 125 - Hora simulada: 10:25
# Preparando ejecución... N=495, Pendientes=33
# Ciclo 125 OK → 495 tareas | Costo total: 1216 | PPF: 1.76
# Ordenes restantes: 79234
#
#  Ciclo 126 - Hora simulada: 10:30
# Preparando ejecución... N=502, Pendientes=41
# Ciclo 126 OK → 502 tareas | Costo total: 1170 | PPF: 1.81
# Ordenes restantes: 78732
#
#  Ciclo 127 - Hora simulada: 10:35
# Preparando ejecución... N=660, Pendientes=19
# Ciclo 127 OK → 660 tareas | Costo total: 1442 | PPF: 1.93
# Ordenes restantes: 78072
#
#  Ciclo 128 - Hora simulada: 10:40
# Preparando ejecución... N=576, Pendientes=34
# Ciclo 128 OK → 576 tareas | Costo total: 1269 | PPF: 1.93
# Ordenes restantes: 77496
#
#  Ciclo 129 - Hora simulada: 10:45
# Preparando ejecución... N=600, Pendientes=45
# Ciclo 129 OK → 600 tareas | Costo total: 1421 | PPF: 1.81
# Ordenes restantes: 76896
#
#  Ciclo 130 - Hora simulada: 10:50
# Preparando ejecución... N=565, Pendientes=11
# Ciclo 130 OK → 565 tareas | Costo total: 1357 | PPF: 1.83
# Ordenes restantes: 76331
#
#  Ciclo 131 - Hora simulada: 10:55
# Preparando ejecución... N=669, Pendientes=6
# Ciclo 131 OK → 669 tareas | Costo total: 1510 | PPF: 1.91
# Ordenes restantes: 75662
#
#  Ciclo 132 - Hora simulada: 11:00
# Preparando ejecución... N=600, Pendientes=99
# Ciclo 132 OK → 600 tareas | Costo total: 1393 | PPF: 1.88
# Ordenes restantes: 75062
#
#  Ciclo 133 - Hora simulada: 11:05
# Preparando ejecución... N=451, Pendientes=23
# Ciclo 133 OK → 451 tareas | Costo total: 1087 | PPF: 1.81
# Ordenes restantes: 74611
#
#  Ciclo 134 - Hora simulada: 11:10
# Preparando ejecución... N=639, Pendientes=94
# Ciclo 134 OK → 639 tareas | Costo total: 1309 | PPF: 2.05
# Ordenes restantes: 73972
#
#  Ciclo 135 - Hora simulada: 11:15
# Preparando ejecución... N=573, Pendientes=44
# Ciclo 135 OK → 573 tareas | Costo total: 1263 | PPF: 1.90
# Ordenes restantes: 73399
#
#  Ciclo 136 - Hora simulada: 11:20
# Preparando ejecución... N=435, Pendientes=13
# Ciclo 136 OK → 435 tareas | Costo total: 1019 | PPF: 1.84
# Ordenes restantes: 72964
#
#  Ciclo 137 - Hora simulada: 11:25
# Preparando ejecución... N=682, Pendientes=16
# Ciclo 137 OK → 682 tareas | Costo total: 1485 | PPF: 1.92
# Ordenes restantes: 72282
#
#  Ciclo 138 - Hora simulada: 11:30
# Preparando ejecución... N=721, Pendientes=61
# Ciclo 138 OK → 721 tareas | Costo total: 1540 | PPF: 1.94
# Ordenes restantes: 71561
#
#  Ciclo 139 - Hora simulada: 11:35
# Preparando ejecución... N=579, Pendientes=3
# Ciclo 139 OK → 579 tareas | Costo total: 1258 | PPF: 1.92
# Ordenes restantes: 70982
#
#  Ciclo 140 - Hora simulada: 11:40
# Preparando ejecución... N=624, Pendientes=2
# Ciclo 140 OK → 624 tareas | Costo total: 1378 | PPF: 1.94
# Ordenes restantes: 70358
#
#  Ciclo 141 - Hora simulada: 11:45
# Preparando ejecución... N=566, Pendientes=80
# Ciclo 141 OK → 566 tareas | Costo total: 1330 | PPF: 1.84
# Ordenes restantes: 69792
#
#  Ciclo 142 - Hora simulada: 11:50
# Preparando ejecución... N=589, Pendientes=40
# Ciclo 142 OK → 589 tareas | Costo total: 1344 | PPF: 1.89
# Ordenes restantes: 69203
#
#  Ciclo 143 - Hora simulada: 11:55
# Preparando ejecución... N=538, Pendientes=78
# Ciclo 143 OK → 538 tareas | Costo total: 1220 | PPF: 1.88
# Ordenes restantes: 68665
#
#  Ciclo 144 - Hora simulada: 12:00
# Preparando ejecución... N=598, Pendientes=20
# Ciclo 144 OK → 598 tareas | Costo total: 1402 | PPF: 1.81
# Ordenes restantes: 68067
#
#  Ciclo 145 - Hora simulada: 12:05
# Preparando ejecución... N=534, Pendientes=81
# Ciclo 145 OK → 534 tareas | Costo total: 1239 | PPF: 1.84
# Ordenes restantes: 67533
#
#  Ciclo 146 - Hora simulada: 12:10
# Preparando ejecución... N=468, Pendientes=81
# Ciclo 146 OK → 468 tareas | Costo total: 1128 | PPF: 1.79
# Ordenes restantes: 67065
#
#  Ciclo 147 - Hora simulada: 12:15
# Preparando ejecución... N=640, Pendientes=24
# Ciclo 147 OK → 640 tareas | Costo total: 1338 | PPF: 1.96
# Ordenes restantes: 66425
#
#  Ciclo 148 - Hora simulada: 12:20
# Preparando ejecución... N=443, Pendientes=7
# Ciclo 148 OK → 443 tareas | Costo total: 1003 | PPF: 1.90
# Ordenes restantes: 65982
#
#  Ciclo 149 - Hora simulada: 12:25
# Preparando ejecución... N=545, Pendientes=66
# Ciclo 149 OK → 545 tareas | Costo total: 1215 | PPF: 1.93
# Ordenes restantes: 65437
#
#  Ciclo 150 - Hora simulada: 12:30
# Preparando ejecución... N=558, Pendientes=53
# Ciclo 150 OK → 558 tareas | Costo total: 1243 | PPF: 1.96
# Ordenes restantes: 64879
#
#  Ciclo 151 - Hora simulada: 12:35
# Preparando ejecución... N=499, Pendientes=36
# Ciclo 151 OK → 499 tareas | Costo total: 1162 | PPF: 1.89
# Ordenes restantes: 64380
#
#  Ciclo 152 - Hora simulada: 12:40
# Preparando ejecución... N=507, Pendientes=93
# Ciclo 152 OK → 507 tareas | Costo total: 1178 | PPF: 1.82
# Ordenes restantes: 63873
#
#  Ciclo 153 - Hora simulada: 12:45
# Preparando ejecución... N=519, Pendientes=29
# Ciclo 153 OK → 519 tareas | Costo total: 1139 | PPF: 1.90
# Ordenes restantes: 63354
#
#  Ciclo 154 - Hora simulada: 12:50
# Preparando ejecución... N=594, Pendientes=72
# Ciclo 154 OK → 594 tareas | Costo total: 1331 | PPF: 1.92
# Ordenes restantes: 62760
#
#  Ciclo 155 - Hora simulada: 12:55
# Preparando ejecución... N=510, Pendientes=22
# Ciclo 155 OK → 510 tareas | Costo total: 1154 | PPF: 1.90
# Ordenes restantes: 62250
#
#  Ciclo 156 - Hora simulada: 13:00
# Preparando ejecución... N=553, Pendientes=51
# Ciclo 156 OK → 553 tareas | Costo total: 1231 | PPF: 1.87
# Ordenes restantes: 61697
#
#  Ciclo 157 - Hora simulada: 13:05
# Preparando ejecución... N=645, Pendientes=63
# Ciclo 157 OK → 645 tareas | Costo total: 1421 | PPF: 1.89
# Ordenes restantes: 61052
#
#  Ciclo 158 - Hora simulada: 13:10
# Preparando ejecución... N=619, Pendientes=88
# Ciclo 158 OK → 619 tareas | Costo total: 1405 | PPF: 1.85
# Ordenes restantes: 60433
#
#  Ciclo 159 - Hora simulada: 13:15
# Preparando ejecución... N=608, Pendientes=33
# Ciclo 159 OK → 608 tareas | Costo total: 1340 | PPF: 1.92
# Ordenes restantes: 59825
#
#  Ciclo 160 - Hora simulada: 13:20
# Preparando ejecución... N=709, Pendientes=24
# Ciclo 160 OK → 709 tareas | Costo total: 1581 | PPF: 1.87
# Ordenes restantes: 59116
#
#  Ciclo 161 - Hora simulada: 13:25
# Preparando ejecución... N=501, Pendientes=89
# Ciclo 161 OK → 501 tareas | Costo total: 1139 | PPF: 1.93
# Ordenes restantes: 58615
#
#  Ciclo 162 - Hora simulada: 13:30
# Preparando ejecución... N=412, Pendientes=12
# Ciclo 162 OK → 412 tareas | Costo total: 967 | PPF: 1.77
# Ordenes restantes: 58203
#
#  Ciclo 163 - Hora simulada: 13:35
# Preparando ejecución... N=406, Pendientes=91
# Ciclo 163 OK → 406 tareas | Costo total: 962 | PPF: 1.81
# Ordenes restantes: 57797
#
#  Ciclo 164 - Hora simulada: 13:40
# Preparando ejecución... N=602, Pendientes=95
# Ciclo 164 OK → 602 tareas | Costo total: 1298 | PPF: 1.98
# Ordenes restantes: 57195
#
#  Ciclo 165 - Hora simulada: 13:45
# Preparando ejecución... N=614, Pendientes=31
# Ciclo 165 OK → 614 tareas | Costo total: 1350 | PPF: 1.91
# Ordenes restantes: 56581
#
#  Ciclo 166 - Hora simulada: 13:50
# Preparando ejecución... N=584, Pendientes=37
# Ciclo 166 OK → 584 tareas | Costo total: 1285 | PPF: 1.91
# Ordenes restantes: 55997
#
#  Ciclo 167 - Hora simulada: 13:55
# Preparando ejecución... N=550, Pendientes=98
# Ciclo 167 OK → 550 tareas | Costo total: 1233 | PPF: 1.88
# Ordenes restantes: 55447
#
#  Ciclo 168 - Hora simulada: 14:00
# Preparando ejecución... N=485, Pendientes=38
# Ciclo 168 OK → 485 tareas | Costo total: 1118 | PPF: 1.87
# Ordenes restantes: 54962
#
#  Ciclo 169 - Hora simulada: 14:05
# Preparando ejecución... N=525, Pendientes=100
# Ciclo 169 OK → 525 tareas | Costo total: 1219 | PPF: 1.83
# Ordenes restantes: 54437
#
#  Ciclo 170 - Hora simulada: 14:10
# Preparando ejecución... N=463, Pendientes=62
# Ciclo 170 OK → 463 tareas | Costo total: 989 | PPF: 2.02
# Ordenes restantes: 53974
#
#  Ciclo 171 - Hora simulada: 14:15
# Preparando ejecución... N=569, Pendientes=74
# Ciclo 171 OK → 569 tareas | Costo total: 1188 | PPF: 2.05
# Ordenes restantes: 53405
#
#  Ciclo 172 - Hora simulada: 14:20
# Preparando ejecución... N=498, Pendientes=47
# Ciclo 172 OK → 498 tareas | Costo total: 1096 | PPF: 1.95
# Ordenes restantes: 52907
#
#  Ciclo 173 - Hora simulada: 14:25
# Preparando ejecución... N=605, Pendientes=33
# Ciclo 173 OK → 605 tareas | Costo total: 1380 | PPF: 1.86
# Ordenes restantes: 52302
#
#  Ciclo 174 - Hora simulada: 14:30
# Preparando ejecución... N=623, Pendientes=41
# Ciclo 174 OK → 623 tareas | Costo total: 1488 | PPF: 1.84
# Ordenes restantes: 51679
#
#  Ciclo 175 - Hora simulada: 14:35
# Preparando ejecución... N=460, Pendientes=36
# Ciclo 175 OK → 460 tareas | Costo total: 1077 | PPF: 1.80
# Ordenes restantes: 51219
#
#  Ciclo 176 - Hora simulada: 14:40
# Preparando ejecución... N=486, Pendientes=38
# Ciclo 176 OK → 486 tareas | Costo total: 1137 | PPF: 1.88
# Ordenes restantes: 50733
#
#  Ciclo 177 - Hora simulada: 14:45
# Preparando ejecución... N=344, Pendientes=3
# Ciclo 177 OK → 344 tareas | Costo total: 777 | PPF: 1.94
# Ordenes restantes: 50389
#
#  Ciclo 178 - Hora simulada: 14:50
# Preparando ejecución... N=621, Pendientes=28
# Ciclo 178 OK → 621 tareas | Costo total: 1361 | PPF: 1.97
# Ordenes restantes: 49768
#
#  Ciclo 179 - Hora simulada: 14:55
# Preparando ejecución... N=574, Pendientes=71
# Ciclo 179 OK → 574 tareas | Costo total: 1235 | PPF: 1.97
# Ordenes restantes: 49194
#
#  Ciclo 180 - Hora simulada: 15:00
# Preparando ejecución... N=522, Pendientes=55
# Ciclo 180 OK → 522 tareas | Costo total: 1179 | PPF: 1.93
# Ordenes restantes: 48672
#
#  Ciclo 181 - Hora simulada: 15:05
# Preparando ejecución... N=569, Pendientes=86
# Ciclo 181 OK → 569 tareas | Costo total: 1354 | PPF: 1.81
# Ordenes restantes: 48103
#
#  Ciclo 182 - Hora simulada: 15:10
# Preparando ejecución... N=519, Pendientes=20
# Ciclo 182 OK → 519 tareas | Costo total: 1208 | PPF: 1.81
# Ordenes restantes: 47584
#
#  Ciclo 183 - Hora simulada: 15:15
# Preparando ejecución... N=519, Pendientes=99
# Ciclo 183 OK → 519 tareas | Costo total: 1102 | PPF: 2.00
# Ordenes restantes: 47065
#
#  Ciclo 184 - Hora simulada: 15:20
# Preparando ejecución... N=580, Pendientes=22
# Ciclo 184 OK → 580 tareas | Costo total: 1316 | PPF: 1.91
# Ordenes restantes: 46485
#
#  Ciclo 185 - Hora simulada: 15:25
# Preparando ejecución... N=637, Pendientes=55
# Ciclo 185 OK → 637 tareas | Costo total: 1415 | PPF: 1.89
# Ordenes restantes: 45848
#
#  Ciclo 186 - Hora simulada: 15:30
# Preparando ejecución... N=584, Pendientes=16
# Ciclo 186 OK → 584 tareas | Costo total: 1336 | PPF: 1.86
# Ordenes restantes: 45264
#
#  Ciclo 187 - Hora simulada: 15:35
# Preparando ejecución... N=422, Pendientes=92
# Ciclo 187 OK → 422 tareas | Costo total: 905 | PPF: 1.96
# Ordenes restantes: 44842
#
#  Ciclo 188 - Hora simulada: 15:40
# Preparando ejecución... N=484, Pendientes=36
# Ciclo 188 OK → 484 tareas | Costo total: 1105 | PPF: 1.83
# Ordenes restantes: 44358
#
#  Ciclo 189 - Hora simulada: 15:45
# Preparando ejecución... N=604, Pendientes=92
# Ciclo 189 OK → 604 tareas | Costo total: 1303 | PPF: 1.97
# Ordenes restantes: 43754
#
#  Ciclo 190 - Hora simulada: 15:50
# Preparando ejecución... N=488, Pendientes=70
# Ciclo 190 OK → 488 tareas | Costo total: 1081 | PPF: 1.94
# Ordenes restantes: 43266
#
#  Ciclo 191 - Hora simulada: 15:55
# Preparando ejecución... N=484, Pendientes=95
# Ciclo 191 OK → 484 tareas | Costo total: 1102 | PPF: 1.92
# Ordenes restantes: 42782
#
#  Ciclo 192 - Hora simulada: 16:00
# Preparando ejecución... N=404, Pendientes=54
# Ciclo 192 OK → 404 tareas | Costo total: 932 | PPF: 1.91
# Ordenes restantes: 42378
#
#  Ciclo 193 - Hora simulada: 16:05
# Preparando ejecución... N=615, Pendientes=10
# Ciclo 193 OK → 615 tareas | Costo total: 1430 | PPF: 1.85
# Ordenes restantes: 41763
#
#  Ciclo 194 - Hora simulada: 16:10
# Preparando ejecución... N=488, Pendientes=3
# Ciclo 194 OK → 488 tareas | Costo total: 1129 | PPF: 1.88
# Ordenes restantes: 41275
#
#  Ciclo 195 - Hora simulada: 16:15
# Preparando ejecución... N=562, Pendientes=29
# Ciclo 195 OK → 562 tareas | Costo total: 1306 | PPF: 1.87
# Ordenes restantes: 40713
#
#  Ciclo 196 - Hora simulada: 16:20
# Preparando ejecución... N=495, Pendientes=47
# Ciclo 196 OK → 495 tareas | Costo total: 1162 | PPF: 1.83
# Ordenes restantes: 40218
#
#  Ciclo 197 - Hora simulada: 16:25
# Preparando ejecución... N=485, Pendientes=8
# Ciclo 197 OK → 485 tareas | Costo total: 1116 | PPF: 1.89
# Ordenes restantes: 39733
#
#  Ciclo 198 - Hora simulada: 16:30
# Preparando ejecución... N=440, Pendientes=7
# Ciclo 198 OK → 440 tareas | Costo total: 919 | PPF: 2.01
# Ordenes restantes: 39293
#
#  Ciclo 199 - Hora simulada: 16:35
# Preparando ejecución... N=518, Pendientes=13
# Ciclo 199 OK → 518 tareas | Costo total: 1130 | PPF: 1.99
# Ordenes restantes: 38775
#
#  Ciclo 200 - Hora simulada: 16:40
# Preparando ejecución... N=466, Pendientes=52
# Ciclo 200 OK → 466 tareas | Costo total: 1087 | PPF: 1.89
# Ordenes restantes: 38309
#
#  Ciclo 201 - Hora simulada: 16:45
# Preparando ejecución... N=422, Pendientes=99
# Ciclo 201 OK → 422 tareas | Costo total: 876 | PPF: 2.09
# Ordenes restantes: 37887
#
#  Ciclo 202 - Hora simulada: 16:50
# Preparando ejecución... N=532, Pendientes=52
# Ciclo 202 OK → 532 tareas | Costo total: 1237 | PPF: 1.82
# Ordenes restantes: 37355
#
#  Ciclo 203 - Hora simulada: 16:55
# Preparando ejecución... N=473, Pendientes=47
# Ciclo 203 OK → 473 tareas | Costo total: 1029 | PPF: 1.96
# Ordenes restantes: 36882
#
#  Ciclo 204 - Hora simulada: 17:00
# Preparando ejecución... N=453, Pendientes=78
# Ciclo 204 OK → 453 tareas | Costo total: 1082 | PPF: 1.81
# Ordenes restantes: 36429
#
#  Ciclo 205 - Hora simulada: 17:05
# Preparando ejecución... N=546, Pendientes=86
# Ciclo 205 OK → 546 tareas | Costo total: 1126 | PPF: 2.05
# Ordenes restantes: 35883
#
#  Ciclo 206 - Hora simulada: 17:10
# Preparando ejecución... N=349, Pendientes=13
# Ciclo 206 OK → 349 tareas | Costo total: 795 | PPF: 1.93
# Ordenes restantes: 35534
#
#  Ciclo 207 - Hora simulada: 17:15
# Preparando ejecución... N=586, Pendientes=16
# Ciclo 207 OK → 586 tareas | Costo total: 1258 | PPF: 1.99
# Ordenes restantes: 34948
#
#  Ciclo 208 - Hora simulada: 17:20
# Preparando ejecución... N=370, Pendientes=11
# Ciclo 208 OK → 370 tareas | Costo total: 879 | PPF: 1.80
# Ordenes restantes: 34578
#
#  Ciclo 209 - Hora simulada: 17:25
# Preparando ejecución... N=438, Pendientes=23
# Ciclo 209 OK → 438 tareas | Costo total: 1001 | PPF: 1.86
# Ordenes restantes: 34140
#
#  Ciclo 210 - Hora simulada: 17:30
# Preparando ejecución... N=530, Pendientes=29
# Ciclo 210 OK → 530 tareas | Costo total: 1160 | PPF: 1.88
# Ordenes restantes: 33610
#
#  Ciclo 211 - Hora simulada: 17:35
# Preparando ejecución... N=510, Pendientes=55
# Ciclo 211 OK → 510 tareas | Costo total: 1120 | PPF: 1.98
# Ordenes restantes: 33100
#
#  Ciclo 212 - Hora simulada: 17:40
# Preparando ejecución... N=473, Pendientes=12
# Ciclo 212 OK → 473 tareas | Costo total: 1157 | PPF: 1.78
# Ordenes restantes: 32627
#
#  Ciclo 213 - Hora simulada: 17:45
# Preparando ejecución... N=484, Pendientes=34
# Ciclo 213 OK → 484 tareas | Costo total: 1050 | PPF: 1.97
# Ordenes restantes: 32143
#
#  Ciclo 214 - Hora simulada: 17:50
# Preparando ejecución... N=516, Pendientes=37
# Ciclo 214 OK → 516 tareas | Costo total: 1124 | PPF: 2.02
# Ordenes restantes: 31627
#
#  Ciclo 215 - Hora simulada: 17:55
# Preparando ejecución... N=402, Pendientes=38
# Ciclo 215 OK → 402 tareas | Costo total: 919 | PPF: 1.91
# Ordenes restantes: 31225
#
#  Ciclo 216 - Hora simulada: 18:00
# Preparando ejecución... N=540, Pendientes=63
# Ciclo 216 OK → 540 tareas | Costo total: 1258 | PPF: 1.82
# Ordenes restantes: 30685
#
#  Ciclo 217 - Hora simulada: 18:05
# Preparando ejecución... N=453, Pendientes=78
# Ciclo 217 OK → 453 tareas | Costo total: 1040 | PPF: 1.87
# Ordenes restantes: 30232
#
#  Ciclo 218 - Hora simulada: 18:10
# Preparando ejecución... N=509, Pendientes=78
# Ciclo 218 OK → 509 tareas | Costo total: 1147 | PPF: 1.91
# Ordenes restantes: 29723
#
#  Ciclo 219 - Hora simulada: 18:15
# Preparando ejecución... N=373, Pendientes=80
# Ciclo 219 OK → 373 tareas | Costo total: 841 | PPF: 1.87
# Ordenes restantes: 29350
#
#  Ciclo 220 - Hora simulada: 18:20
# Preparando ejecución... N=508, Pendientes=44
# Ciclo 220 OK → 508 tareas | Costo total: 1127 | PPF: 1.92
# Ordenes restantes: 28842
#
#  Ciclo 221 - Hora simulada: 18:25
# Preparando ejecución... N=520, Pendientes=27
# Ciclo 221 OK → 520 tareas | Costo total: 1169 | PPF: 1.90
# Ordenes restantes: 28322
#
#  Ciclo 222 - Hora simulada: 18:30
# Preparando ejecución... N=413, Pendientes=100
# Ciclo 222 OK → 413 tareas | Costo total: 942 | PPF: 1.89
# Ordenes restantes: 27909
#
#  Ciclo 223 - Hora simulada: 18:35
# Preparando ejecución... N=459, Pendientes=52
# Ciclo 223 OK → 459 tareas | Costo total: 1026 | PPF: 1.90
# Ordenes restantes: 27450
#
#  Ciclo 224 - Hora simulada: 18:40
# Preparando ejecución... N=531, Pendientes=39
# Ciclo 224 OK → 531 tareas | Costo total: 1125 | PPF: 1.99
# Ordenes restantes: 26919
#
#  Ciclo 225 - Hora simulada: 18:45
# Preparando ejecución... N=380, Pendientes=40
# Ciclo 225 OK → 380 tareas | Costo total: 819 | PPF: 1.97
# Ordenes restantes: 26539
#
#  Ciclo 226 - Hora simulada: 18:50
# Preparando ejecución... N=398, Pendientes=34
# Ciclo 226 OK → 398 tareas | Costo total: 891 | PPF: 1.92
# Ordenes restantes: 26141
#
#  Ciclo 227 - Hora simulada: 18:55
# Preparando ejecución... N=374, Pendientes=2
# Ciclo 227 OK → 374 tareas | Costo total: 824 | PPF: 2.01
# Ordenes restantes: 25767
#
#  Ciclo 228 - Hora simulada: 19:00
# Preparando ejecución... N=426, Pendientes=32
# Ciclo 228 OK → 426 tareas | Costo total: 991 | PPF: 1.83
# Ordenes restantes: 25341
#
#  Ciclo 229 - Hora simulada: 19:05
# Preparando ejecución... N=463, Pendientes=72
# Ciclo 229 OK → 463 tareas | Costo total: 1011 | PPF: 1.97
# Ordenes restantes: 24878
#
#  Ciclo 230 - Hora simulada: 19:10
# Preparando ejecución... N=494, Pendientes=47
# Ciclo 230 OK → 494 tareas | Costo total: 1160 | PPF: 1.87
# Ordenes restantes: 24384
#
#  Ciclo 231 - Hora simulada: 19:15
# Preparando ejecución... N=572, Pendientes=46
# Ciclo 231 OK → 572 tareas | Costo total: 1220 | PPF: 1.95
# Ordenes restantes: 23812
#
#  Ciclo 232 - Hora simulada: 19:20
# Preparando ejecución... N=475, Pendientes=49
# Ciclo 232 OK → 475 tareas | Costo total: 973 | PPF: 2.09
# Ordenes restantes: 23337
#
#  Ciclo 233 - Hora simulada: 19:25
# Preparando ejecución... N=373, Pendientes=33
# Ciclo 233 OK → 373 tareas | Costo total: 907 | PPF: 1.82
# Ordenes restantes: 22964
#
#  Ciclo 234 - Hora simulada: 19:30
# Preparando ejecución... N=380, Pendientes=8
# Ciclo 234 OK → 380 tareas | Costo total: 853 | PPF: 1.97
# Ordenes restantes: 22584
#
#  Ciclo 235 - Hora simulada: 19:35
# Preparando ejecución... N=551, Pendientes=44
# Ciclo 235 OK → 551 tareas | Costo total: 1168 | PPF: 2.03
# Ordenes restantes: 22033
#
#  Ciclo 236 - Hora simulada: 19:40
# Preparando ejecución... N=314, Pendientes=3
# Ciclo 236 OK → 314 tareas | Costo total: 788 | PPF: 1.73
# Ordenes restantes: 21719
#
#  Ciclo 237 - Hora simulada: 19:45
# Preparando ejecución... N=473, Pendientes=81
# Ciclo 237 OK → 473 tareas | Costo total: 1041 | PPF: 1.96
# Ordenes restantes: 21246
#
#  Ciclo 238 - Hora simulada: 19:50
# Preparando ejecución... N=480, Pendientes=92
# Ciclo 238 OK → 480 tareas | Costo total: 1101 | PPF: 1.90
# Ordenes restantes: 20766
#
#  Ciclo 239 - Hora simulada: 19:55
# Preparando ejecución... N=388, Pendientes=92
# Ciclo 239 OK → 388 tareas | Costo total: 929 | PPF: 1.89
# Ordenes restantes: 20378
#
#  Ciclo 240 - Hora simulada: 20:00
# Preparando ejecución... N=518, Pendientes=43
# Ciclo 240 OK → 518 tareas | Costo total: 1154 | PPF: 1.92
# Ordenes restantes: 19860
#
#  Ciclo 241 - Hora simulada: 20:05
# Preparando ejecución... N=524, Pendientes=9
# Ciclo 241 OK → 524 tareas | Costo total: 1166 | PPF: 1.93
# Ordenes restantes: 19336
#
#  Ciclo 242 - Hora simulada: 20:10
# Preparando ejecución... N=439, Pendientes=34
# Ciclo 242 OK → 439 tareas | Costo total: 971 | PPF: 1.99
# Ordenes restantes: 18897
#
#  Ciclo 243 - Hora simulada: 20:15
# Preparando ejecución... N=454, Pendientes=90
# Ciclo 243 OK → 454 tareas | Costo total: 896 | PPF: 2.16
# Ordenes restantes: 18443
#
#  Ciclo 244 - Hora simulada: 20:20
# Preparando ejecución... N=428, Pendientes=86
# Ciclo 244 OK → 428 tareas | Costo total: 971 | PPF: 1.89
# Ordenes restantes: 18015
#
#  Ciclo 245 - Hora simulada: 20:25
# Preparando ejecución... N=421, Pendientes=35
# Ciclo 245 OK → 421 tareas | Costo total: 986 | PPF: 1.85
# Ordenes restantes: 17594
#
#  Ciclo 246 - Hora simulada: 20:30
# Preparando ejecución... N=521, Pendientes=22
# Ciclo 246 OK → 521 tareas | Costo total: 1152 | PPF: 1.94
# Ordenes restantes: 17073
#
#  Ciclo 247 - Hora simulada: 20:35
# Preparando ejecución... N=382, Pendientes=22
# Ciclo 247 OK → 382 tareas | Costo total: 861 | PPF: 1.94
# Ordenes restantes: 16691
#
#  Ciclo 248 - Hora simulada: 20:40
# Preparando ejecución... N=424, Pendientes=11
# Ciclo 248 OK → 424 tareas | Costo total: 974 | PPF: 1.93
# Ordenes restantes: 16267
#
#  Ciclo 249 - Hora simulada: 20:45
# Preparando ejecución... N=426, Pendientes=89
# Ciclo 249 OK → 426 tareas | Costo total: 935 | PPF: 2.02
# Ordenes restantes: 15841
#
#  Ciclo 250 - Hora simulada: 20:50
# Preparando ejecución... N=402, Pendientes=31
# Ciclo 250 OK → 402 tareas | Costo total: 901 | PPF: 1.91
# Ordenes restantes: 15439
#
#  Ciclo 251 - Hora simulada: 20:55
# Preparando ejecución... N=362, Pendientes=55
# Ciclo 251 OK → 362 tareas | Costo total: 813 | PPF: 2.00
# Ordenes restantes: 15077
#
#  Ciclo 252 - Hora simulada: 21:00
# Preparando ejecución... N=476, Pendientes=35
# Ciclo 252 OK → 476 tareas | Costo total: 989 | PPF: 2.06
# Ordenes restantes: 14601
#
#  Ciclo 253 - Hora simulada: 21:05
# Preparando ejecución... N=414, Pendientes=34
# Ciclo 253 OK → 414 tareas | Costo total: 893 | PPF: 1.98
# Ordenes restantes: 14187
#
#  Ciclo 254 - Hora simulada: 21:10
# Preparando ejecución... N=417, Pendientes=77
# Ciclo 254 OK → 417 tareas | Costo total: 942 | PPF: 1.88
# Ordenes restantes: 13770
#
#  Ciclo 255 - Hora simulada: 21:15
# Preparando ejecución... N=513, Pendientes=91
# Ciclo 255 OK → 513 tareas | Costo total: 1115 | PPF: 2.00
# Ordenes restantes: 13257
#
#  Ciclo 256 - Hora simulada: 21:20
# Preparando ejecución... N=421, Pendientes=83
# Ciclo 256 OK → 421 tareas | Costo total: 945 | PPF: 1.90
# Ordenes restantes: 12836
#
#  Ciclo 257 - Hora simulada: 21:25
# Preparando ejecución... N=433, Pendientes=94
# Ciclo 257 OK → 433 tareas | Costo total: 953 | PPF: 1.92
# Ordenes restantes: 12403
#
#  Ciclo 258 - Hora simulada: 21:30
# Preparando ejecución... N=518, Pendientes=29
# Ciclo 258 OK → 518 tareas | Costo total: 1114 | PPF: 1.95
# Ordenes restantes: 11885
#
#  Ciclo 259 - Hora simulada: 21:35
# Preparando ejecución... N=329, Pendientes=9
# Ciclo 259 OK → 329 tareas | Costo total: 798 | PPF: 1.83
# Ordenes restantes: 11556
#
#  Ciclo 260 - Hora simulada: 21:40
# Preparando ejecución... N=422, Pendientes=72
# Ciclo 260 OK → 422 tareas | Costo total: 887 | PPF: 2.08
# Ordenes restantes: 11134
#
#  Ciclo 261 - Hora simulada: 21:45
# Preparando ejecución... N=368, Pendientes=86
# Ciclo 261 OK → 368 tareas | Costo total: 775 | PPF: 2.08
# Ordenes restantes: 10766
#
#  Ciclo 262 - Hora simulada: 21:50
# Preparando ejecución... N=416, Pendientes=15
# Ciclo 262 OK → 416 tareas | Costo total: 875 | PPF: 2.03
# Ordenes restantes: 10350
#
#  Ciclo 263 - Hora simulada: 21:55
# Preparando ejecución... N=436, Pendientes=41
# Ciclo 263 OK → 436 tareas | Costo total: 985 | PPF: 1.89
# Ordenes restantes: 9914
#
#  Ciclo 264 - Hora simulada: 22:00
# Preparando ejecución... N=393, Pendientes=18
# Ciclo 264 OK → 393 tareas | Costo total: 961 | PPF: 1.81
# Ordenes restantes: 9521
#
#  Ciclo 265 - Hora simulada: 22:05
# Preparando ejecución... N=474, Pendientes=44
# Ciclo 265 OK → 474 tareas | Costo total: 1055 | PPF: 1.98
# Ordenes restantes: 9047
#
#  Ciclo 266 - Hora simulada: 22:10
# Preparando ejecución... N=429, Pendientes=21
# Ciclo 266 OK → 429 tareas | Costo total: 968 | PPF: 1.90
# Ordenes restantes: 8618
#
#  Ciclo 267 - Hora simulada: 22:15
# Preparando ejecución... N=298, Pendientes=18
# Ciclo 267 OK → 298 tareas | Costo total: 668 | PPF: 1.94
# Ordenes restantes: 8320
#
#  Ciclo 268 - Hora simulada: 22:20
# Preparando ejecución... N=395, Pendientes=66
# Ciclo 268 OK → 395 tareas | Costo total: 841 | PPF: 2.05
# Ordenes restantes: 7925
#
#  Ciclo 269 - Hora simulada: 22:25
# Preparando ejecución... N=333, Pendientes=53
# Ciclo 269 OK → 333 tareas | Costo total: 730 | PPF: 1.98
# Ordenes restantes: 7592
#
#  Ciclo 270 - Hora simulada: 22:30
# Preparando ejecución... N=287, Pendientes=1
# Ciclo 270 OK → 287 tareas | Costo total: 666 | PPF: 1.86
# Ordenes restantes: 7305
#
#  Ciclo 271 - Hora simulada: 22:35
# Preparando ejecución... N=478, Pendientes=32
# Ciclo 271 OK → 478 tareas | Costo total: 982 | PPF: 2.12
# Ordenes restantes: 6827
#
#  Ciclo 272 - Hora simulada: 22:40
# Preparando ejecución... N=441, Pendientes=30
# Ciclo 272 OK → 441 tareas | Costo total: 969 | PPF: 1.93
# Ordenes restantes: 6386
#
#  Ciclo 273 - Hora simulada: 22:45
# Preparando ejecución... N=461, Pendientes=52
# Ciclo 273 OK → 461 tareas | Costo total: 1039 | PPF: 1.90
# Ordenes restantes: 5925
#
#  Ciclo 274 - Hora simulada: 22:50
# Preparando ejecución... N=357, Pendientes=19
# Ciclo 274 OK → 357 tareas | Costo total: 803 | PPF: 1.97
# Ordenes restantes: 5568
#
#  Ciclo 275 - Hora simulada: 22:55
# Preparando ejecución... N=442, Pendientes=61
# Ciclo 275 OK → 442 tareas | Costo total: 953 | PPF: 2.00
# Ordenes restantes: 5126
#
#  Ciclo 276 - Hora simulada: 23:00
# Preparando ejecución... N=421, Pendientes=98
# Ciclo 276 OK → 421 tareas | Costo total: 978 | PPF: 1.91
# Ordenes restantes: 4705
#
#  Ciclo 277 - Hora simulada: 23:05
# Preparando ejecución... N=456, Pendientes=77
# Ciclo 277 OK → 456 tareas | Costo total: 948 | PPF: 2.05
# Ordenes restantes: 4249
#
#  Ciclo 278 - Hora simulada: 23:10
# Preparando ejecución... N=344, Pendientes=47
# Ciclo 278 OK → 344 tareas | Costo total: 779 | PPF: 1.86
# Ordenes restantes: 3905
#
#  Ciclo 279 - Hora simulada: 23:15
# Preparando ejecución... N=417, Pendientes=77
# Ciclo 279 OK → 417 tareas | Costo total: 907 | PPF: 2.05
# Ordenes restantes: 3488
#
#  Ciclo 280 - Hora simulada: 23:20
# Preparando ejecución... N=366, Pendientes=41
# Ciclo 280 OK → 366 tareas | Costo total: 905 | PPF: 1.80
# Ordenes restantes: 3122
#
#  Ciclo 281 - Hora simulada: 23:25
# Preparando ejecución... N=386, Pendientes=61
# Ciclo 281 OK → 386 tareas | Costo total: 855 | PPF: 1.92
# Ordenes restantes: 2736
#
#  Ciclo 282 - Hora simulada: 23:30
# Preparando ejecución... N=427, Pendientes=51
# Ciclo 282 OK → 427 tareas | Costo total: 943 | PPF: 1.91
# Ordenes restantes: 2309
#
#  Ciclo 283 - Hora simulada: 23:35
# Preparando ejecución... N=412, Pendientes=10
# Ciclo 283 OK → 412 tareas | Costo total: 879 | PPF: 1.95
# Ordenes restantes: 1897
#
#  Ciclo 284 - Hora simulada: 23:40
# Preparando ejecución... N=344, Pendientes=8
# Ciclo 284 OK → 344 tareas | Costo total: 805 | PPF: 1.86
# Ordenes restantes: 1553
#
#  Ciclo 285 - Hora simulada: 23:45
# Preparando ejecución... N=341, Pendientes=31
# Ciclo 285 OK → 341 tareas | Costo total: 771 | PPF: 1.93
# Ordenes restantes: 1212
#
#  Ciclo 286 - Hora simulada: 23:50
# Preparando ejecución... N=433, Pendientes=13
# Ciclo 286 OK → 433 tareas | Costo total: 919 | PPF: 2.07
# Ordenes restantes: 779
#
#  Ciclo 287 - Hora simulada: 23:55
# Preparando ejecución... N=345, Pendientes=48
# Ciclo 287 OK → 345 tareas | Costo total: 829 | PPF: 1.83
# Ordenes restantes: 434
#
#  Ciclo 288 - Hora simulada: 00:00
# Preparando ejecución... N=434, Pendientes=19
# Ciclo 288 OK → 434 tareas | Costo total: 913 | PPF: 1.96
# Ordenes restantes: 0
#
#  Ordenes totales cumplidas: 171746
#
#  Costo final: 386459
#
#  Promedio de costo por paquete por ciclo: [2.5644490644490645, 2.21875, 2.341207349081365, 2.292490118577075, 2.0668103448275863, 2.3892445582586426, 2.2896969696969696, 2.2150055991041433, 2.1536772777167945, 2.2672998643147895, 2.269182389937107, 2.2323788546255505, 2.2364945978391355, 2.2071494042163153, 2.209812108559499, 2.125531914893617, 2.3291614518147683, 2.1149032992036405, 2.2262773722627736, 2.1902497027348393, 2.400726392251816, 2.217948717948718, 2.1764091858037578, 2.157387580299786, 2.4038216560509555, 2.297650130548303, 2.2680301399354144, 2.418282548476454, 2.4221183800623054, 2.206258890469417, 2.2791817087845967, 2.223844282238443, 2.2550607287449393, 2.2912, 2.278688524590164, 2.337062937062937, 2.198547215496368, 2.1743929359823397, 2.2158536585365853, 2.1396648044692737, 2.3043478260869565, 2.275656324582339, 2.260969976905312, 2.214994487320838, 2.1487303506650544, 2.2527646129541865, 2.304140127388535, 2.324797843665768, 2.264748201438849, 2.3351877607788594, 2.134961439588689, 2.3152585119798235, 2.1633906633906634, 2.324396782841823, 2.295208655332303, 2.3848797250859106, 2.3162393162393164, 2.3725190839694656, 2.2816537467700257, 2.2037444933920707, 2.401840490797546, 2.2109375, 2.1188571428571428, 2.154046997389034, 2.278706800445931, 2.371900826446281, 2.219409282700422, 2.1542699724517904, 2.231707317073171, 2.3608247422680413, 2.4019337016574585, 2.183533447684391, 2.135327635327635, 2.413612565445026, 2.3132183908045976, 2.1933174224343674, 2.2804097311139566, 2.3763277693474962, 2.4640234948604993, 2.2393162393162394, 2.294701986754967, 2.301164725457571, 2.351925630810093, 2.1159217877094973, 2.318936877076412, 2.3614088820826953, 2.317241379310345, 2.209235209235209, 2.2923497267759565, 2.3163120567375888, 2.225473321858864, 2.3608087091757386, 2.221732745961821, 2.3302325581395347, 2.235127478753541, 2.3693430656934305, 2.3289473684210527, 2.229059829059829, 2.0926174496644294, 2.3054331864904554, 2.1534482758620688, 2.235114503816794, 2.5036764705882355, 2.1092436974789917, 2.1758241758241756, 2.235747303543914, 2.2456896551724137, 2.174193548387097, 2.301302931596091, 2.1295418641390205, 2.281150159744409, 2.209103840682788, 2.1816838995568686, 2.2395693135935395, 2.183063511830635, 2.3118594436310396, 2.3480662983425415, 2.2222222222222223, 2.138957816377171, 2.2712177121771218, 2.4050880626223092, 2.1942544459644324, 2.113382899628253, 2.1907308377896615, 2.4565656565656564, 2.3306772908366535, 2.184848484848485, 2.203125, 2.368333333333333, 2.4017699115044246, 2.2571001494768312, 2.3216666666666668, 2.41019955654102, 2.048513302034429, 2.2041884816753927, 2.342528735632184, 2.1774193548387095, 2.1359223300970873, 2.1727115716753023, 2.2083333333333335, 2.34982332155477, 2.2818336162988118, 2.2676579925650557, 2.3444816053511706, 2.3202247191011236, 2.41025641025641, 2.090625, 2.2641083521444694, 2.229357798165138, 2.227598566308244, 2.3286573146292584, 2.323471400394477, 2.1946050096339116, 2.240740740740741, 2.2627450980392156, 2.2260397830018084, 2.2031007751937985, 2.269789983844911, 2.2039473684210527, 2.229901269393512, 2.273453093812375, 2.3470873786407767, 2.3694581280788176, 2.1561461794019934, 2.198697068403909, 2.2003424657534247, 2.2418181818181817, 2.3051546391752575, 2.321904761904762, 2.136069114470842, 2.0878734622144113, 2.2008032128514055, 2.28099173553719, 2.388443017656501, 2.341304347826087, 2.3395061728395063, 2.258720930232558, 2.1916264090177133, 2.1515679442508713, 2.2586206896551726, 2.3796133567662565, 2.327552986512524, 2.123314065510597, 2.268965517241379, 2.2213500784929354, 2.287671232876712, 2.1445497630331753, 2.2830578512396693, 2.1572847682119205, 2.2151639344262297, 2.2768595041322315, 2.3069306930693068, 2.3252032520325203, 2.3135245901639343, 2.323843416370107, 2.3474747474747475, 2.3010309278350514, 2.088636363636364, 2.1814671814671813, 2.332618025751073, 2.075829383886256, 2.325187969924812, 2.175475687103594, 2.3885209713024285, 2.06227106227106 ...
#
#  Racks únicos utilizados: 203(99.86%)
#
#  Promedio de cantidad de caras usadas en un ciclo: 317.34
#
#  Promedio caras usadas por racks usados: 1.09
#
#  Promedio diario de Picks per Face: 1.89
#
#  Costo promedio por orden: 2.25
#
#  Tasa de cumplimiento SLA: 100.0%
#
#  Tiempo promedio de ejecución por ciclo: 0.35 segundos
